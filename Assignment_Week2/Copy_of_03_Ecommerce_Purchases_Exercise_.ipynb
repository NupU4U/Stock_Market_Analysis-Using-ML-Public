# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../../Pierian_Data_Logo.png' /></a>
# ___
# # Ecommerce Purchases Exercise
#
# In this Exercise you will be given some Fake Data about some purchases done through Amazon! Just go ahead and follow the directions and try your best to answer the questions and complete the tasks. Feel free to reference the solutions. Most of the tasks can be solved in different ways. For the most part, the questions get progressively harder.
#
# Please excuse anything that doesn't make "Real-World" sense in the dataframe, all the data is fake and made-up.
#
# Also note that all of these questions can be answered with one line of code.
# ____
# ** Import pandas and read in the Ecommerce Purchases csv file and set it to a DataFrame called ecom. **

# %%
import pandas as pd

# %%
ecom = pd.read_csv("Ecommerce_Purchases.csv")

# %% [markdown]
# **Check the head of the DataFrame.**

# %%
ecom.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# 2       Simpson, Williams and Pham      675957666125       08/19
# 3  Williams, Marshall and Buchanan  6011578504430710       02/24
# 4        Brown, Watson and Andrews  6011456623207998       10/25
#
#    CC Security Code                  CC Provider  \
# 0               900                 JCB 16 digit
# 1               561                   Mastercard
# 2               699                 JCB 16 digit
# 3               384                     Discover
# 4               678  Diners Club / Carte Blanche
#
#                             Email                                     Job  \
# 0               pdunlap@yahoo.com  Scientist, product/process development
# 1              anthony41@reed.com                       Drilling engineer
# 2  amymiller@morales-harrison.com                Customer service manager
# 3     brent16@olson-robinson.info                       Drilling engineer
# 4     christopherwright@gmail.com                             Fine artist
#
#         IP Address Language  Purchase Price
# 0  149.146.147.205       el           98.14
# 1     15.160.41.51       fr           70.73
# 2   132.207.160.22       de            0.95
# 3     30.250.74.19       es           78.04
# 4     24.140.33.94       es           77.82

# %% [markdown]
# ** How many rows and columns are there? **

# %%
ecom.shape
# Out:
# (10000, 14)

# %% [markdown]
# ** What is the average Purchase Price? **

# %%
ecom["Purchase Price"].mean()
# Out:
# 50.34730200000025

# %% [markdown]
# ** What were the highest and lowest purchase prices? **

# %%
ecom["Purchase Price"].max()
# Out:
# 99.99

# %%
ecom["Purchase Price"].min()
# Out:
# 0.0

# %% [markdown]
# ** How many people have English 'en' as their Language of choice on the website? **

# %%
ecom[ecom["Language"] == "en"].shape[0]
# Out:
# 1098

# %% [markdown]
# ** How many people have the job title of "Lawyer" ? **

# %%
ecom[ecom["Job"] == "Lawyer"].shape[0]
# Out:
# 30

# %% [markdown]
# ** How many people made the purchase during the AM and how many people made the purchase during PM ? **
#
# **(Hint: Check out [value_counts()](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html) ) **

# %%
print(ecom.groupby("AM or PM").get_group("PM").shape[0])
ecom.groupby("AM or PM").get_group("AM").shape[0]
# Out:
# 5068
# 4932

# %% [markdown]
# ** What are the 5 most common Job Titles? **

# %%
ecom['Job'].value_counts().head()
# Out:
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
# Name: Job, dtype: int64

# %% [markdown]
# ** Someone made a purchase that came from Lot: "90 WT" , what was the Purchase Price for this transaction? **

# %%
ecom[ecom["Lot"] == "90 WT"]["Purchase Price"]
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %% [markdown]
# ** What is the email of the person with the following Credit Card Number: 4926535242672853 **

# %%
ecom[ecom["Credit Card"] == 4926535242672853]["Email"]
# Out:
# 1234    bondellen@williams-garza.com
# Name: Email, dtype: object

# %% [markdown]
# ** How many people have American Express as their Credit Card Provider *and* made a purchase above $95 ?**

# %%
ecom[(ecom["CC Provider"] == "American Express") & (ecom["Purchase Price"] > 95.0)]
# Out:
#                                                 Address    Lot AM or PM  \
# 9       3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
# 280   81060 Dustin Causeway Apt. 503\nPort Danielche...  80 zh       PM
# 372              359 Stanley Coves\nSalasfort, SD 59457  75 Ub       PM
# 677       4855 Peter Bridge\nJohnsonberg, PA 90599-0009  62 Nx       AM
# 766             386 Alisha Unions\nSteelebury, ND 19782  28 pJ       PM
# 1225    916 Amanda Heights\nNew Johnland, CA 52112-8572  09 vg       PM
# 1381  79284 Lisa Mews Suite 069\nKellyborough, CT 71...  45 MR       PM
# 1385  67796 James Keys Suite 656\nSouth Katieshire, ...  06 ia       PM
# 1568       76108 Barker Manors\nEast Amy, PW 49544-5921  82 Qw       AM
# 1727  478 Anita Hill Apt. 766\nAverymouth, FM 50629-...  94 qM       AM
# 2146           557 Barton Harbor\nFuentesport, VI 29961  96 MV       AM
# 2264   040 Ingram Way Suite 602\nEast Matthew, AR 67341  52 WA       AM
# 2267  216 Olivia Court Apt. 439\nTonyshire, IN 19159...  11 za       PM
# 2642  899 Williams Prairie Suite 234\nEast Hunterbur...  46 hb       PM
# 2828  20135 Miller Green Apt. 763\nGarciaville, KY 6...  79 El       PM
# 3291             58939 Reese Cove\nSouth Ross, MA 54531  50 cD       AM
# 3349  1984 Christopher Turnpike Suite 904\nRichardbu...  30 xs       AM
# 3619  03233 Angela Road Apt. 808\nEast Jilliantown, ...  41 nH       PM
# 4071  8161 Craig Passage Apt. 939\nPort Emilystad, R...  45 ab       AM
# 4569  88284 Austin Summit Apt. 805\nKellerside, WY 6...  03 WL       AM
# 5385                           USNS Smith\nFPO AA 37829  80 BX       AM
# 5655       38674 Mckay Vista\nWilsonbury, MO 55611-8663  95 aB       PM
# 5692                   PSC 8264, Box 8124\nAPO AE 19700  97 sG       PM
# 5814              Unit 5232 Box 4650\nDPO AE 28335-7543  71 So       PM
# 5875      8256 Anderson Forest\nFordbury, PA 81027-8980  17 Oe       AM
# 5895  87003 Jason Tunnel Apt. 216\nDariusville, MS 8...  72 gL       AM
# 6026                   Unit 4385 Box 1428\nDPO AE 04110  58 Ex       AM
# 6524  344 Rivera Shore Apt. 224\nJoshuaborough, ND 3...  44 SM       AM
# 7239        81561 Stein Rue\nEast Melissaport, MA 64959  45 sZ       PM
# 7381  40804 Belinda Roads Apt. 186\nWest Nicoleberg,...  30 GH       AM
# 7416    1082 Jason Alley Suite 707\nWhitestad, SC 97805  08 bm       PM
# 7514    678 David Manor Suite 323\nBobbymouth, PW 59942  91 NA       AM
# 8233  327 Hamilton Hollow\nEast Nicolechester, RI 65868  53 dE       PM
# 8381  274 Wallace Pine Apt. 189\nMartinberg, WY 7548...  32 rI       PM
# 8408                   Unit 4967 Box 4574\nDPO AP 11412  05 zs       PM
# 8434  474 Gonzalez Meadow Suite 581\nEast Vincent, M...  14 St       PM
# 8817          3658 Campos Lodge\nChambersfurt, MH 86260  24 ej       PM
# 9168  18782 Hall Row Suite 810\nSouth Wesleyville, I...  15 QU       PM
# 9856  058 Miranda Locks Suite 792\nPort Davidstad, P...  73 IW       PM
#
#                                            Browser Info  \
# 9     Mozilla/5.0 (X11; Linux i686; rv:1.9.7.20) Gec...
# 280   Mozilla/5.0 (Windows NT 5.01) AppleWebKit/5362...
# 372   Opera/8.42.(X11; Linux x86_64; en-US) Presto/2...
# 677   Opera/9.49.(Windows 98; Win 9x 4.90; en-US) Pr...
# 766   Opera/8.47.(X11; Linux x86_64; sl-SI) Presto/2...
# 1225  Mozilla/5.0 (X11; Linux i686; rv:1.9.7.20) Gec...
# 1381  Mozilla/5.0 (Macintosh; PPC Mac OS X 10_5_5; r...
# 1385  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/5330 ...
# 1568  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 1727  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 2146  Mozilla/5.0 (compatible; MSIE 6.0; Windows 98;...
# 2264  Mozilla/5.0 (Windows NT 6.0) AppleWebKit/5341 ...
# 2267  Mozilla/5.0 (Macintosh; PPC Mac OS X 10_6_4; r...
# 2642  Mozilla/5.0 (compatible; MSIE 7.0; Windows NT ...
# 2828  Mozilla/5.0 (Windows; U; Windows CE) AppleWebK...
# 3291  Mozilla/5.0 (compatible; MSIE 9.0; Windows 95;...
# 3349  Mozilla/5.0 (X11; Linux x86_64; rv:1.9.7.20) G...
# 3619  Opera/9.53.(Windows 95; en-US) Presto/2.9.175 ...
# 4071  Mozilla/5.0 (Windows; U; Windows NT 6.1) Apple...
# 4569  Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_5_5...
# 5385  Opera/9.56.(X11; Linux x86_64; en-US) Presto/2...
# 5655  Mozilla/5.0 (X11; Linux i686) AppleWebKit/5331...
# 5692  Mozilla/5.0 (iPod; U; CPU iPhone OS 3_3 like M...
# 5814  Mozilla/5.0 (X11; Linux i686) AppleWebKit/5342...
# 5875  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 5895  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 6026  Mozilla/5.0 (Windows; U; Windows NT 5.01) Appl...
# 6524  Opera/8.62.(X11; Linux i686; en-US) Presto/2.9...
# 7239  Mozilla/5.0 (X11; Linux i686) AppleWebKit/5310...
# 7381  Opera/9.32.(Windows NT 4.0; it-IT) Presto/2.9....
# 7416  Mozilla/5.0 (Windows NT 5.1; sl-SI; rv:1.9.2.2...
# 7514  Mozilla/5.0 (compatible; MSIE 8.0; Windows 98;...
# 8233  Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_5_3...
# 8381  Mozilla/5.0 (Windows; U; Windows 98; Win 9x 4....
# 8408  Mozilla/5.0 (compatible; MSIE 5.0; Windows 98;...
# 8434  Mozilla/5.0 (compatible; MSIE 6.0; Windows NT ...
# 8817  Mozilla/5.0 (compatible; MSIE 5.0; Windows NT ...
# 9168  Opera/9.57.(X11; Linux i686; it-IT) Presto/2.9...
# 9856  Mozilla/5.0 (Windows NT 5.0) AppleWebKit/5360 ...
#
#                             Company       Credit Card CC Exp Date  \
# 9      Rivera, Buchanan and Ramirez     4396283918371       01/17
# 280                        Clay PLC   377737470673585       10/17
# 372                  Davis-Lawrence   371995567939253       02/26
# 677                  Jones and Sons  4960556611626434       07/26
# 766                     Proctor PLC    30325623350308       04/24
# 1225         Clark, Ross and Travis   371229555854245       10/21
# 1381                  Randall-Cohen     4855262855037       05/17
# 1385      Gonzalez, Gross and Allen    30407332938506       12/20
# 1568       Nguyen, Branch and Wiley  5142451859832464       04/21
# 1727                  Owen and Sons    30242757909967       11/19
# 2146                    Flores-Cook  3337255995040373       04/19
# 2264       Baker, Simmons and Pitts  3096946456575623       11/22
# 2267                      Olson Inc  5388757330269354       02/17
# 2642                       Webb Inc  3096797127305092       05/17
# 2828         Zavala, Cox and Parker  5173968976288215       11/22
# 3291        Chang, Davis and Snyder   349464844934636       11/23
# 3349                Martin-Mitchell  3096398727024637       03/19
# 3619        Silva, Kim and Martinez  4807251488895729       10/21
# 4071                Wilson-Robinson  5506767693718324       08/23
# 4569     Fisher, Thompson and Lynch  3088726880694574       12/19
# 5385               Patterson-Miller  4411786056713950       12/22
# 5655                  Watson-Bailey  3096820981608615       05/20
# 5692                      Moore Inc  6011499701167585       10/20
# 5814                     Garcia LLC    30346960979608       07/17
# 5875     Kelly, Peterson and Oliver  5173335726386576       02/18
# 5895          Reyes, Fox and Wilson   180010957603245       09/24
# 6026                      White Inc  3112975578138572       09/17
# 6524     Lawson, Moyer and Valencia   379348662534664       06/17
# 7239                      Smith Ltd      503825682670       07/19
# 7381                    Blair-Keith   180089858618619       05/19
# 7416  Carroll, Harrison and Escobar  3088903707645291       12/18
# 7514           Glenn, Lowe and Shah      676298897445       04/26
# 8233      Keller, Carter and Garcia    30299608736429       08/22
# 8381                   Kelly-Newman  5527104423944290       05/18
# 8408                  Acevedo-Smith  3337721305744244       01/19
# 8434                Miller and Sons   180059754370698       07/24
# 8817                   Fisher-Jones   210046575239925       09/25
# 9168                     Butler PLC  5412611065926441       05/25
# 9856                  Olson-Navarro  6011037226242937       03/18
#
#       CC Security Code       CC Provider  \
# 9                  931  American Express
# 280                349  American Express
# 372               1877  American Express
# 677               9255  American Express
# 766                772  American Express
# 1225               366  American Express
# 1381               518  American Express
# 1385               597  American Express
# 1568               785  American Express
# 1727              7403  American Express
# 2146                28  American Express
# 2264                56  American Express
# 2267               738  American Express
# 2642               418  American Express
# 2828               125  American Express
# 3291               103  American Express
# 3349               439  American Express
# 3619               948  American Express
# 4071                18  American Express
# 4569               159  American Express
# 5385               452  American Express
# 5655               259  American Express
# 5692               845  American Express
# 5814               402  American Express
# 5875               954  American Express
# 5895               929  American Express
# 6026                 7  American Express
# 6524               809  American Express
# 7239               852  American Express
# 7381              2107  American Express
# 7416               220  American Express
# 7514                61  American Express
# 8233               786  American Express
# 8381               711  American Express
# 8408               738  American Express
# 8434               812  American Express
# 8817               860  American Express
# 9168                49  American Express
# 9856               757  American Express
#
#                                        Email  \
# 9                   qcoleman@hunt-huerta.com
# 280                        hfarley@hicks.com
# 372                      amberhull@jones.net
# 677                 evanskayla@fernandez.com
# 766                 robertsonjulia@gmail.com
# 1225                lawrencecarter@kelly.com
# 1381  maldonadomichael@martinez-delgado.info
# 1385                    vbrown@daugherty.com
# 1568                  johnsonjulie@yahoo.com
# 1727          sharpmelanie@smith-johnson.com
# 2146           jessica94@mosley-buchanan.com
# 2264                    holtamanda@gmail.com
# 2267          burkestephanie@lee-cameron.com
# 2642                  reevesmanuel@gmail.com
# 2828                villarrealdavid@gray.com
# 3291               stephanieacosta@yahoo.com
# 3349                 hgross@mccoy-mckay.info
# 3619                  jonesjesse@castro.info
# 4071                    hhenderson@yahoo.com
# 4569                        amy00@patton.com
# 5385                      ijones@hotmail.com
# 5655                   timothy84@hotmail.com
# 5692                     kellypace@yahoo.com
# 5814                         jrice@gmail.com
# 5875               hernandezandrea@yahoo.com
# 5895               duncanmichael@hotmail.com
# 6026                       scott35@yahoo.com
# 6524                   olsonjohn@hotmail.com
# 7239                beckerjennifer@gmail.com
# 7381                 woodsmatthew@walton.org
# 7416                        gcruz@butler.com
# 7514                     tammy75@cameron.com
# 8233                   elliskaren@taylor.com
# 8381                    joneswilliam@cox.net
# 8408                  nunezjames@hotmail.com
# 8434                    vtaylor@hatfield.com
# 8817                   jessica35@hotmail.com
# 9168                    tammyblair@yahoo.com
# 9856               brendastewart@dalton.info
#
#                                                Job       IP Address Language  \
# 9                               Forensic scientist    236.198.199.8       zh
# 280                                     Ergonomist    134.52.148.32       de
# 372               Training and development officer    198.98.34.250       pt
# 677                       Plant breeder/geneticist   235.97.240.112       el
# 766                                 Therapist, art    146.208.30.83       es
# 1225                                        Artist     88.49.59.205       pt
# 1381                    Geophysical data processor    50.40.147.204       it
# 1385                    Geophysical data processor  152.133.246.191       zh
# 1568                      Insurance claims handler  175.248.232.126       es
# 1727   Psychologist, prison and probation services    126.47.196.22       ru
# 2146                Armed forces technical officer     35.97.189.19       es
# 2264                                 Archaeologist   185.14.106.115       es
# 2267                         Management consultant    20.140.16.225       it
# 2642                    Engineer, maintenance (IT)  169.132.152.152       el
# 2828               Chartered management accountant     76.75.229.58       el
# 3291                                    IT trainer  124.247.101.106       it
# 3349                           Structural engineer   167.172.139.33       pt
# 3619                  Garment/textile technologist       87.66.16.4       en
# 4071                      Customer service manager    119.74.76.168       es
# 4569                                       Actuary     207.18.223.8       el
# 5385                            Field seismologist  251.254.250.100       el
# 5655  Production designer, theatre/television/film  235.149.102.129       es
# 5692                                    Aid worker    155.121.60.58       pt
# 5814                                     Solicitor   165.48.161.188       zh
# 5875                  Community development worker   212.168.246.27       ru
# 5895                               Event organiser    231.34.199.32       it
# 6026                          Operations geologist    217.6.202.138       en
# 6524                       Teacher, primary school      45.1.104.55       zh
# 7239                              Engineer, energy   50.107.135.203       fr
# 7381                              Fashion designer    223.87.136.82       es
# 7416                           Broadcast presenter    193.90.91.152       pt
# 7514                           Automotive engineer   37.241.180.247       ru
# 8233                             Chemical engineer   131.34.220.138       en
# 8381                      Surveyor, land/geomatics   29.211.114.191       ru
# 8408                  Designer, exhibition/display    91.55.254.144       es
# 8434                Armed forces technical officer     26.69.128.20       it
# 8817                            Forensic scientist    18.74.143.113       fr
# 9168                      Computer games developer      2.84.51.133       en
# 9856                                 Site engineer    96.79.250.154       de
#
#       Purchase Price
# 9              95.63
# 280            99.13
# 372            99.08
# 677            98.97
# 766            96.66
# 1225           96.55
# 1381           96.11
# 1385           98.89
# 1568           97.04
# 1727           95.58
# 2146           98.01
# 2264           99.85
# 2267           97.63
# 2642           96.08
# 2828           96.12
# 3291           95.94
# 3349           95.46
# 3619           99.69
# 4071           96.49
# 4569           97.38
# 5385           96.13
# 5655           98.28
# 5692           98.66
# 5814           96.73
# 5875           95.07
# 5895           97.38
# 6026           95.89
# 6524           97.87
# 7239           97.32
# 7381           99.81
# 7416           96.09
# 7514           98.36
# 8233           98.63
# 8381           99.36
# 8408           98.16
# 8434           97.90
# 8817           99.16
# 9168           98.59
# 9856           99.97

# %% [markdown]
# ** Hard: How many people have a credit card that expires in 2025? **

# %%
count = 0
for i in ecom["CC Exp Date"]:
  list1 = i.split("/")
  if list1[1] == "25":
    count += 1
  else:
    continue
count
# Out:
# 1033

# %% [markdown]
# ** Hard: What are the top 5 most popular email providers/hosts (e.g. gmail.com, yahoo.com, etc...) **

# %%
for i in ecom["Email"]:
  domain = i.split("@")
  print(domain)
# Out:
# Streaming output truncated to the last 5000 lines.
# ['susan99', 'mann.com']
# ['edwardwest', 'hendrix.biz']
# ['tanya09', 'gmail.com']
# ['carolynscott', 'roberts.com']
# ['rholden', 'brown-west.com']
# ['wjimenez', 'harris-bell.info']
# ['shardin', 'yahoo.com']
# ['iray', 'hotmail.com']
# ['adrian15', 'stewart.com']
# ['ruben46', 'craig-nichols.com']
# ['canderson', 'hotmail.com']
# ['tylerpaul', 'hotmail.com']
# ['gthornton', 'yahoo.com']
# ['kimberlywalker', 'hotmail.com']
# ['greenjames', 'bailey-branch.biz']
# ['davidrobinson', 'yahoo.com']
# ['hoffmanhector', 'smith.com']
# ['christian46', 'gmail.com']
# ['fsmith', 'fox.com']
# ['evananderson', 'yahoo.com']
# ['marshallstacy', 'avila.com']
# ['molly10', 'hotmail.com']
# ['kimberlyhicks', 'gmail.com']
# ['lewisjames', 'miller.com']
# ['karenjames', 'hotmail.com']
# ['pattersonkendra', 'moses.com']
# ['tracy04', 'crane.com']
# ['eric95', 'hotmail.com']
# ['paulamanda', 'hotmail.com']
# ['khill', 'hotmail.com']
# ['isaiahpark', 'yahoo.com']
# ['navarrotony', 'yahoo.com']
# ['sarahwillis', 'davis-graham.org']
# ['ksmith', 'hotmail.com']
# ['angelawalsh', 'hotmail.com']
# ['tamara60', 'yahoo.com']
# ['lisacampbell', 'decker-buchanan.com']
# ['gburnett', 'preston.com']
# ['linda93', 'yahoo.com']
# ['melissaflowers', 'yahoo.com']
# ['grayrick', 'yahoo.com']
# ['branchsteven', 'doyle.info']
# ['mpaul', 'barnes.biz']
# ['kimberly07', 'gmail.com']
# ['facosta', 'miranda.com']
# ['morgantammy', 'king.com']
# ['kelleralan', 'salinas.com']
# ['wrightjohn', 'mayer.net']
# ['bakerjohnny', 'dawson.com']
# ['alvaradosteve', 'gmail.com']
# ['hkim', 'kline-anthony.info']
# ['theresafitzpatrick', 'wells.com']
# ['pgreene', 'hotmail.com']
# ['alisonblackwell', 'lewis.com']
# ['sspence', 'hoffman-brooks.com']
# ['fhernandez', 'armstrong.com']
# ['xcummings', 'simon-dean.com']
# ['yaustin', 'hotmail.com']
# ['kjohnson', 'gmail.com']
# ['griffinsarah', 'ritter.com']
# ['vwood', 'gonzales.com']
# ['johnhenderson', 'watkins.com']
# ['ibrown', 'villa-white.info']
# ['jamescarson', 'gmail.com']
# ['emilymartinez', 'king.com']
# ['jessicabutler', 'gmail.com']
# ['sheliahill', 'mendoza-burke.com']
# ['joseph59', 'lopez.biz']
# ['lawrenceharry', 'long-santos.org']
# ['carrie75', 'schmidt.biz']
# ['michaelmiranda', 'roth.com']
# ['davidpayne', 'adams.org']
# ['jwilliams', 'gmail.com']
# ['ccortez', 'yahoo.com']
# ['lambertvirginia', 'yahoo.com']
# ['johnbutler', 'webb-daniels.com']
# ['johnsonjill', 'hotmail.com']
# ['barry45', 'lee-phillips.com']
# ['brenda43', 'hotmail.com']
# ['ofuller', 'gmail.com']
# ['ellistracey', 'johnson.com']
# ['angela59', 'diaz.org']
# ['florespatrick', 'house.com']
# ['leemichael', 'yahoo.com']
# ['amber01', 'oconnor.info']
# ['newmanvanessa', 'caldwell.com']
# ['gwilson', 'blake.org']
# ['tlopez', 'yahoo.com']
# ['kingmonica', 'guerrero.com']
# ['emily10', 'yahoo.com']
# ['holly32', 'keller-park.com']
# ['micheal24', 'willis.org']
# ['lisa73', 'hotmail.com']
# ['hkirby', 'coffey.net']
# ['grantmichael', 'hotmail.com']
# ['williamsmartin', 'gmail.com']
# ['ydavis', 'moreno.com']
# ['kathybennett', 'hotmail.com']
# ['michael29', 'walsh-moore.com']
# ['cassidyunderwood', 'hayes.com']
# ['mooreedward', 'gmail.com']
# ['apatton', 'gmail.com']
# ['pkim', 'fields-johnson.com']
# ['escott', 'murphy.net']
# ['icarlson', 'espinoza.com']
# ['qford', 'thompson.com']
# ['daniel80', 'yahoo.com']
# ['ericaliu', 'donaldson.com']
# ['vickidunlap', 'smith.org']
# ['alexandertran', 'cain-banks.com']
# ['tmueller', 'trevino.net']
# ['kevin45', 'yahoo.com']
# ['iramos', 'gmail.com']
# ['aaron49', 'gmail.com']
# ['joel09', 'lyons-porter.info']
# ['dwhite', 'brooks.com']
# ['cynthia80', 'burgess-brown.biz']
# ['hartmandana', 'carpenter.com']
# ['szamora', 'watson-ramos.info']
# ['angietrevino', 'hotmail.com']
# ['iramos', 'yahoo.com']
# ['kyleatkinson', 'gmail.com']
# ['kimmurphy', 'gmail.com']
# ['douglasmerritt', 'joyce.com']
# ['amber99', 'hotmail.com']
# ['taraclements', 'pruitt.com']
# ['umiller', 'harper.org']
# ['wilsonnicholas', 'castillo.net']
# ['solisjames', 'hughes-humphrey.net']
# ['katrinawilliams', 'carter-patel.net']
# ['michael29', 'martin-diaz.com']
# ['jonesdaniel', 'hotmail.com']
# ['iewing', 'hotmail.com']
# ['wesley72', 'yahoo.com']
# ['erik57', 'guerra.com']
# ['nancy11', 'long.com']
# ['aliu', 'figueroa-arnold.com']
# ['heathermyers', 'gmail.com']
# ['eguerrero', 'mitchell-yates.com']
# ['alejandrocurtis', 'hotmail.com']
# ['donald21', 'roman.com']
# ['rsmith', 'white.com']
# ['myersjason', 'hicks-kim.net']
# ['bradley09', 'baker.com']
# ['matthewwalker', 'boyd.com']
# ['natalieavila', 'yahoo.com']
# ['wharris', 'rodriguez.info']
# ['elizabethjones', 'yahoo.com']
# ['ashleybriggs', 'hotmail.com']
# ['joseph25', 'yahoo.com']
# ['brandylowe', 'brown-frederick.com']
# ['smithjoseph', 'johnson.info']
# ['marissahahn', 'yahoo.com']
# ['carriemartinez', 'anderson.com']
# ['maryroberts', 'hotmail.com']
# ['edwardsjohn', 'gmail.com']
# ['colemantaylor', 'douglas-cooper.com']
# ['dawnperez', 'hotmail.com']
# ['linda84', 'ross.net']
# ['morrisontony', 'hotmail.com']
# ['bparker', 'wells.com']
# ['davistimothy', 'gmail.com']
# ['andreafrey', 'turner-cline.com']
# ['fitzpatricktammie', 'saunders.org']
# ['riverajulia', 'potter.com']
# ['ogarcia', 'yahoo.com']
# ['littlesteven', 'graham-herrera.info']
# ['joycejohnson', 'diaz.com']
# ['trankatelyn', 'hotmail.com']
# ['ginamorgan', 'johnson-keller.com']
# ['wpotts', 'gmail.com']
# ['lauren59', 'blake.info']
# ['teresa53', 'kerr.com']
# ['craig73', 'gmail.com']
# ['jennifer37', 'hotmail.com']
# ['mstokes', 'clark-nguyen.com']
# ['perryjennifer', 'yahoo.com']
# ['caseypaul', 'hotmail.com']
# ['cameron91', 'walters.net']
# ['nlambert', 'yahoo.com']
# ['nhooper', 'gmail.com']
# ['lorimiller', 'thomas-george.com']
# ['jacksonamy', 'love-patterson.com']
# ['keithwilson', 'gmail.com']
# ['orodriguez', 'burns.net']
# ['marywhite', 'orr-elliott.biz']
# ['lucasheather', 'yahoo.com']
# ['thuerta', 'anderson.info']
# ['hcase', 'martinez.net']
# ['qmann', 'yahoo.com']
# ['billy26', 'gmail.com']
# ['michaelschultz', 'little.com']
# ['brandonallen', 'newman.net']
# ['gsims', 'gmail.com']
# ['jstafford', 'yahoo.com']
# ['gregory82', 'wheeler-parks.net']
# ['amcfarland', 'watson.com']
# ['andersongregory', 'evans.com']
# ['anne90', 'hotmail.com']
# ['michelesanford', 'hayes-pruitt.biz']
# ['kyleharris', 'hotmail.com']
# ['breanna73', 'baird.com']
# ['ijenkins', 'yahoo.com']
# ['misty78', 'hotmail.com']
# ['antonio10', 'gmail.com']
# ['tracyferguson', 'baldwin-sandoval.com']
# ['dustinhutchinson', 'gmail.com']
# ['kylechristensen', 'mann.org']
# ['andrewgarcia', 'lopez.net']
# ['achavez', 'yahoo.com']
# ['xcardenas', 'hotmail.com']
# ['westolivia', 'yahoo.com']
# ['bateslindsey', 'gmail.com']
# ['jordanwoods', 'wilson-brown.com']
# ['debraduke', 'schneider.com']
# ['buckleyjose', 'hotmail.com']
# ['villarrealwilliam', 'yahoo.com']
# ['ericmitchell', 'hotmail.com']
# ['misty03', 'gmail.com']
# ['uray', 'gmail.com']
# ['wowen', 'grant.com']
# ['aaronfigueroa', 'gmail.com']
# ['hopaul', 'flowers-thomas.info']
# ['scummings', 'gmail.com']
# ['jessica66', 'gmail.com']
# ['bethboyd', 'jones.com']
# ['mark75', 'hotmail.com']
# ['tsteele', 'hotmail.com']
# ['zsmith', 'gmail.com']
# ['tricia53', 'gmail.com']
# ['pbarnes', 'hotmail.com']
# ['kevinwatkins', 'hotmail.com']
# ['andersondavid', 'yahoo.com']
# ['singletongregory', 'owens.com']
# ['nschmidt', 'yahoo.com']
# ['lynn47', 'vaughan-huff.com']
# ['chelsea85', 'gmail.com']
# ['kimberly52', 'hotmail.com']
# ['sarahcarey', 'clark-morales.info']
# ['rickywright', 'yahoo.com']
# ['katie08', 'yahoo.com']
# ['tdavis', 'gmail.com']
# ['fmurphy', 'moore.net']
# ['cole51', 'gmail.com']
# ['bbell', 'harris-scott.info']
# ['rhondacallahan', 'yahoo.com']
# ['hintonpatrick', 'robbins.biz']
# ['armstrongalison', 'yahoo.com']
# ['briggsjohn', 'morris.org']
# ['thomas67', 'gmail.com']
# ['melissabonilla', 'russell.com']
# ['emily84', 'church.com']
# ['rebeccahancock', 'dawson.info']
# ['lisastout', 'brown.com']
# ['ctorres', 'williams.com']
# ['tjohnson', 'yahoo.com']
# ['timothy63', 'yahoo.com']
# ['markperkins', 'steele-allison.com']
# ['jonesjames', 'thompson.com']
# ['drodriguez', 'gmail.com']
# ['fyoung', 'gmail.com']
# ['gholmes', 'kemp-humphrey.com']
# ['plambert', 'gmail.com']
# ['christiankrystal', 'yahoo.com']
# ['smithdavid', 'zhang.com']
# ['ryoung', 'payne.org']
# ['vcline', 'yahoo.com']
# ['olsonnicholas', 'coleman-ramos.info']
# ['timothy04', 'welch.com']
# ['rachaelsmith', 'gomez-hicks.com']
# ['erin75', 'gmail.com']
# ['watersderrick', 'hotmail.com']
# ['millerlarry', 'yahoo.com']
# ['tclark', 'gmail.com']
# ['jsteele', 'yahoo.com']
# ['ycunningham', 'spears-robinson.com']
# ['erikakaiser', 'pope.com']
# ['jessicajones', 'white.com']
# ['glenn94', 'smith.org']
# ['cooperpatrick', 'nielsen.com']
# ['guyburton', 'mcgee.com']
# ['tracy58', 'long.biz']
# ['rodneychavez', 'gmail.com']
# ['tserrano', 'hotmail.com']
# ['jasonschultz', 'hotmail.com']
# ['melissawilliams', 'page-schwartz.biz']
# ['xstein', 'yahoo.com']
# ['holly96', 'perez.net']
# ['jamessmith', 'thomas.com']
# ['figueroajasmine', 'hotmail.com']
# ['sharonbell', 'pena.biz']
# ['eugene27', 'jenkins.com']
# ['porterjason', 'peck-ashley.com']
# ['victoriaconley', 'gmail.com']
# ['robertsdonna', 'hotmail.com']
# ['swaller', 'stephenson-myers.net']
# ['lindsayrodriguez', 'allen.com']
# ['brittanyross', 'garcia.com']
# ['griffinkristin', 'hotmail.com']
# ['mcarter', 'yahoo.com']
# ['asanchez', 'hotmail.com']
# ['johnsonwilliam', 'gmail.com']
# ['qcardenas', 'gmail.com']
# ['greencarrie', 'warren.com']
# ['stephen62', 'hotmail.com']
# ['mfernandez', 'gmail.com']
# ['imorgan', 'yahoo.com']
# ['martinezcynthia', 'hartman.com']
# ['jeffery59', 'vaughan.com']
# ['joshua37', 'hotmail.com']
# ['ogonzalez', 'wilkins-rich.net']
# ['zscott', 'yahoo.com']
# ['agonzales', 'foley-henderson.org']
# ['kelly62', 'walker.com']
# ['ogibbs', 'hotmail.com']
# ['sonia46', 'powell-sanford.com']
# ['marcus51', 'rodriguez-sweeney.com']
# ['yanglouis', 'yahoo.com']
# ['xwilliams', 'phillips.info']
# ['christine40', 'hart-lopez.com']
# ['jwatson', 'norris-cross.info']
# ['jeremyrivas', 'hotmail.com']
# ['zrandolph', 'webster-rivera.com']
# ['dmiller', 'lynch.com']
# ['howardtonya', 'sanchez-mccoy.com']
# ['johnsonpatrick', 'hotmail.com']
# ['washingtoncharles', 'hotmail.com']
# ['arodriguez', 'crawford.com']
# ['myersrebekah', 'morrison.net']
# ['savannahwright', 'dixon-evans.info']
# ['angelalewis', 'stevens.com']
# ['grahamabigail', 'hotmail.com']
# ['andersonelizabeth', 'yahoo.com']
# ['kellerlisa', 'gmail.com']
# ['claireburton', 'luna-reynolds.biz']
# ['khernandez', 'yahoo.com']
# ['tabitha13', 'yahoo.com']
# ['oschmitt', 'gmail.com']
# ['pwhite', 'yahoo.com']
# ['benitezbrittany', 'johnson.com']
# ['xsmith', 'black-thompson.net']
# ['rwheeler', 'hotmail.com']
# ['williamsmarco', 'mccarthy.com']
# ['ericaedwards', 'gmail.com']
# ['gouldamanda', 'nash-lewis.biz']
# ['edward88', 'gmail.com']
# ['jay97', 'miller.com']
# ['ryanbowen', 'hart.net']
# ['howardmichael', 'gmail.com']
# ['brianbaxter', 'yahoo.com']
# ['pbarnes', 'gmail.com']
# ['connor43', 'yahoo.com']
# ['ymerritt', 'sandoval-scott.org']
# ['pamela02', 'smith.biz']
# ['elizabethroberts', 'sullivan-harrell.net']
# ['mckaydavid', 'hotmail.com']
# ['nanderson', 'yahoo.com']
# ['hpena', 'mcintyre-brooks.info']
# ['seansanchez', 'lawrence.biz']
# ['vargasjennifer', 'hotmail.com']
# ['larry40', 'gmail.com']
# ['hwalker', 'hotmail.com']
# ['thomaslynch', 'rivera.biz']
# ['joseph55', 'yahoo.com']
# ['christopherduran', 'yahoo.com']
# ['cjohnson', 'gmail.com']
# ['stevenskatherine', 'yahoo.com']
# ['edwardgilmore', 'carroll.org']
# ['odonnellerin', 'hotmail.com']
# ['crawfordbethany', 'hotmail.com']
# ['rsmith', 'porter-klein.com']
# ['christopher87', 'saunders.net']
# ['laurensimpson', 'gmail.com']
# ['joshua05', 'yahoo.com']
# ['uduran', 'jones.com']
# ['smithmichael', 'gmail.com']
# ['villanuevawilliam', 'hotmail.com']
# ['robertmartinez', 'bush.com']
# ['derricksmith', 'turner.com']
# ['michaelterrell', 'hotmail.com']
# ['rachelfrost', 'schneider.com']
# ['gregory58', 'lowery.com']
# ['pattonbeverly', 'willis.com']
# ['gmitchell', 'hotmail.com']
# ['tonyapace', 'hotmail.com']
# ['ijones', 'hotmail.com']
# ['brandon71', 'hotmail.com']
# ['savagethomas', 'hotmail.com']
# ['benjamin50', 'tyler-anderson.com']
# ['michael64', 'yahoo.com']
# ['autumnkelly', 'curtis-evans.com']
# ['marymorrison', 'torres.biz']
# ['mwalker', 'fisher.biz']
# ['christinawalker', 'yahoo.com']
# ['martincheryl', 'thompson.biz']
# ['rkramer', 'walker.com']
# ['singletonanna', 'martinez-wright.com']
# ['kimstephanie', 'thomas.com']
# ['smithanthony', 'brown.com']
# ['brian22', 'phelps-barron.biz']
# ['ycampbell', 'avila-best.org']
# ['jkent', 'hicks.com']
# ['gtaylor', 'brown-flynn.com']
# ['sromero', 'gmail.com']
# ['anthony76', 'hotmail.com']
# ['suzanne64', 'fuentes-cruz.org']
# ['kimamber', 'paul.com']
# ['wmartin', 'paul.biz']
# ['clee', 'yahoo.com']
# ['christopherjennings', 'gmail.com']
# ['anna39', 'martinez.com']
# ['michellevaughan', 'yahoo.com']
# ['moralesrandy', 'melton.org']
# ['qsawyer', 'hotmail.com']
# ['reyesapril', 'gmail.com']
# ['uwoodard', 'hotmail.com']
# ['tranmaria', 'brown-woods.com']
# ['thomaslisa', 'stephenson-callahan.com']
# ['patrickalvarado', 'jenkins.info']
# ['donaldortiz', 'gmail.com']
# ['adamsjose', 'gmail.com']
# ['vmoore', 'sherman.info']
# ['andrewmartin', 'yahoo.com']
# ['jennifer80', 'steele.com']
# ['ihernandez', 'willis.com']
# ['rebecca59', 'richmond-warner.com']
# ['zwright', 'suarez.biz']
# ['judith69', 'yahoo.com']
# ['lbruce', 'yahoo.com']
# ['klee', 'hoffman.info']
# ['hannahblair', 'hotmail.com']
# ['steven67', 'castro.com']
# ['john47', 'young.com']
# ['shannonbarnett', 'pena.net']
# ['montgomerytiffany', 'brown-martin.biz']
# ['rebeccabrown', 'johnson.biz']
# ['regina92', 'taylor.biz']
# ['frenchlisa', 'yahoo.com']
# ['davisjohn', 'hotmail.com']
# ['nealjuan', 'powers.com']
# ['hendersontony', 'hotmail.com']
# ['erobbins', 'gmail.com']
# ['vroberts', 'gmail.com']
# ['jacob57', 'hotmail.com']
# ['hayleyjones', 'little-smith.com']
# ['christianfritz', 'lee.com']
# ['kenneth43', 'brooks.org']
# ['hallstephanie', 'douglas-davis.net']
# ['kathy31', 'butler-harris.com']
# ['pjefferson', 'gmail.com']
# ['cscott', 'yahoo.com']
# ['lovejoseph', 'lee.com']
# ['nwalker', 'yahoo.com']
# ['lori05', 'bowen-wheeler.com']
# ['aduncan', 'williams-smith.com']
# ['aturner', 'keller-turner.org']
# ['jennybennett', 'gmail.com']
# ['banksandrew', 'russell.com']
# ['bolson', 'yahoo.com']
# ['maryray', 'oneal-guerra.com']
# ['vfoley', 'hotmail.com']
# ['silvanatalie', 'hotmail.com']
# ['gutierrezdylan', 'hotmail.com']
# ['josephdiaz', 'diaz-elliott.com']
# ['rogersalyssa', 'cox-newman.com']
# ['eclark', 'hotmail.com']
# ['eric53', 'campbell-dennis.com']
# ['edwardsjohnathan', 'hotmail.com']
# ['ztravis', 'howell-johnson.com']
# ['ryanmclean', 'gmail.com']
# ['makaylasoto', 'hotmail.com']
# ['petersongregory', 'garrett-ramos.com']
# ['lawsonmeredith', 'young.com']
# ['kimberly31', 'adams-taylor.com']
# ['cphillips', 'johnson.com']
# ['erica02', 'hill.com']
# ['ingramjames', 'turner-ward.org']
# ['andrewbishop', 'reynolds.com']
# ['mmeyer', 'hotmail.com']
# ['phuffman', 'gmail.com']
# ['ashleysmith', 'chase.com']
# ['wendy96', 'herrera.com']
# ['ifrazier', 'montes.org']
# ['cguerrero', 'walker-parsons.org']
# ['lburke', 'yahoo.com']
# ['harperlisa', 'cook.biz']
# ['jodimurphy', 'yahoo.com']
# ['mjohnson', 'austin.org']
# ['vgreen', 'hotmail.com']
# ['martinli', 'yahoo.com']
# ['vvaughan', 'hotmail.com']
# ['davidmontes', 'long.org']
# ['collinsdalton', 'hotmail.com']
# ['joseph39', 'smith.org']
# ['aaron54', 'gmail.com']
# ['phillip55', 'gmail.com']
# ['katrina13', 'yahoo.com']
# ['emmamills', 'tanner.com']
# ['devon84', 'yahoo.com']
# ['blackdominique', 'sanchez.biz']
# ['tracy51', 'lowe-porter.info']
# ['melissaboyle', 'price-price.com']
# ['edwardmartin', 'duncan.com']
# ['aaron16', 'hotmail.com']
# ['williamholmes', 'myers.com']
# ['wmiller', 'glenn.info']
# ['cantrelldebbie', 'crosby-arroyo.com']
# ['tharris', 'avila.biz']
# ['willie68', 'thompson-mcconnell.com']
# ['robert26', 'smith.com']
# ['urogers', 'martin-wright.info']
# ['rebeccaflores', 'gmail.com']
# ['natalie76', 'mcdonald.biz']
# ['jadams', 'lambert.biz']
# ['efigueroa', 'powers.net']
# ['hillcarlos', 'hotmail.com']
# ['moraleselizabeth', 'ramos-boyd.org']
# ['udavis', 'hotmail.com']
# ['paigebeck', 'gmail.com']
# ['ywilliams', 'bennett.biz']
# ['connie82', 'hotmail.com']
# ['turnerchristopher', 'hotmail.com']
# ['kristy02', 'gmail.com']
# ['xowens', 'holland.info']
# ['goodwinterrance', 'hotmail.com']
# ['amanda71', 'kim-rodriguez.com']
# ['elizabeth62', 'stone.com']
# ['conwaykevin', 'greer.com']
# ['kclark', 'barnes-cain.com']
# ['jaime42', 'gmail.com']
# ['ywalker', 'guzman.com']
# ['joshuaadams', 'martin.info']
# ['jlopez', 'davis.com']
# ['brendawang', 'harris.com']
# ['david78', 'gmail.com']
# ['maria70', 'hotmail.com']
# ['quinnpaula', 'gmail.com']
# ['ramosrandall', 'hotmail.com']
# ['james55', 'fitzgerald.com']
# ['andersonashley', 'simmons.com']
# ['jessica81', 'williams.biz']
# ['john08', 'gmail.com']
# ['rwallace', 'villarreal-kane.com']
# ['jblake', 'hamilton.com']
# ['ericacarr', 'walker-mccormick.org']
# ['gwalker', 'yahoo.com']
# ['ryan37', 'yahoo.com']
# ['sanchezmeghan', 'lee.net']
# ['kathy72', 'tucker.com']
# ['kevinparker', 'yahoo.com']
# ['sheppardnicholas', 'higgins.com']
# ['stephaniehart', 'nelson.org']
# ['thunter', 'hotmail.com']
# ['alicia36', 'stein-dodson.info']
# ['blackralph', 'reed-carter.com']
# ['kimberlywallace', 'hotmail.com']
# ['larsonerin', 'lopez.biz']
# ['joshuaprice', 'nguyen.com']
# ['sandra82', 'levy-davis.com']
# ['mariathompson', 'henderson.com']
# ['anthonybarry', 'edwards.com']
# ['holtkyle', 'buck.com']
# ['joshua94', 'yahoo.com']
# ['michaelwillis', 'davis.net']
# ['brandonjarvis', 'gmail.com']
# ['rhondamcdonald', 'johnson-bennett.biz']
# ['staffordkevin', 'hotmail.com']
# ['daisywilson', 'moreno.info']
# ['garrettsellers', 'simpson.biz']
# ['melissa56', 'hotmail.com']
# ['donald89', 'yahoo.com']
# ['hansenryan', 'yahoo.com']
# ['rachelperez', 'allen-rodriguez.com']
# ['curryjohn', 'hotmail.com']
# ['mary81', 'davidson.com']
# ['joshua13', 'martinez.com']
# ['christinasilva', 'davis.net']
# ['geoffreybradley', 'logan-price.com']
# ['dcook', 'hotmail.com']
# ['michael57', 'gmail.com']
# ['jwilliams', 'myers-garcia.com']
# ['langdavid', 'gmail.com']
# ['kelsey67', 'yahoo.com']
# ['whitneygarcia', 'yahoo.com']
# ['donaldpowell', 'gmail.com']
# ['xbryant', 'hotmail.com']
# ['chriswilliams', 'gmail.com']
# ['huntermark', 'yahoo.com']
# ['nspears', 'wright-neal.com']
# ['rpatel', 'thomas.com']
# ['hendersonlori', 'monroe-valdez.org']
# ['klong', 'yahoo.com']
# ['theresaramos', 'burton-cooley.com']
# ['wdixon', 'gmail.com']
# ['fguzman', 'williams.com']
# ['nicole87', 'gmail.com']
# ['opeterson', 'henson.com']
# ['robert72', 'chandler.info']
# ['williamvargas', 'hotmail.com']
# ['ericbryant', 'hotmail.com']
# ['xhernandez', 'smith-williams.com']
# ['jbowen', 'stewart.com']
# ['cnorman', 'yahoo.com']
# ['fitzgeraldlisa', 'hotmail.com']
# ['ashley22', 'yahoo.com']
# ['tiffanymendez', 'gmail.com']
# ['ybennett', 'gmail.com']
# ['rosejasmine', 'hotmail.com']
# ['drussell', 'anderson.com']
# ['longgloria', 'perkins.net']
# ['lisa33', 'rosales.info']
# ['miranda32', 'yahoo.com']
# ['mhinton', 'brown-kim.com']
# ['brittney65', 'gmail.com']
# ['jamesbyrd', 'hotmail.com']
# ['katie54', 'boyd.com']
# ['tranlarry', 'black-sullivan.com']
# ['johnsonapril', 'gmail.com']
# ['robert12', 'ramos-moreno.com']
# ['aliciaadams', 'yahoo.com']
# ['betty66', 'kelley.com']
# ['phillipkline', 'sims.com']
# ['pagemichelle', 'yahoo.com']
# ['jacobscheryl', 'gmail.com']
# ['abbottpaula', 'taylor.com']
# ['lisahale', 'gmail.com']
# ['patrickadams', 'gmail.com']
# ['coxronald', 'rowe.com']
# ['hperez', 'gmail.com']
# ['samantha08', 'nguyen-wolfe.com']
# ['heather03', 'hotmail.com']
# ['gthornton', 'johnson.com']
# ['phillip68', 'smith-brooks.com']
# ['jeffreykeith', 'rivers.com']
# ['paulaguirre', 'yahoo.com']
# ['jgomez', 'gmail.com']
# ['carpentererica', 'hotmail.com']
# ['qfitzpatrick', 'ramos-parker.com']
# ['gknight', 'hotmail.com']
# ['nicholassmith', 'yahoo.com']
# ['vsmith', 'gmail.com']
# ['alan40', 'wilson-page.com']
# ['jessicareyes', 'torres.com']
# ['leetonya', 'morton.com']
# ['gregorythompson', 'hotmail.com']
# ['charlotte84', 'maldonado.biz']
# ['margaret91', 'hall-chapman.info']
# ['ybeard', 'smith.com']
# ['rayjamie', 'spencer-shah.com']
# ['qhansen', 'yahoo.com']
# ['patricia29', 'campos-wyatt.com']
# ['randysolomon', 'gmail.com']
# ['vgardner', 'gmail.com']
# ['carrollmichael', 'lyons-allen.com']
# ['bwatson', 'yahoo.com']
# ['timothy84', 'hotmail.com']
# ['shawn00', 'hotmail.com']
# ['kosborne', 'patton.org']
# ['vmurphy', 'byrd.com']
# ['ricardomurray', 'smith-hall.com']
# ['colleengarcia', 'yahoo.com']
# ['jamesreynolds', 'mcmahon-wilson.com']
# ['prattsamantha', 'duarte.net']
# ['ophillips', 'gmail.com']
# ['christian94', 'gmail.com']
# ['cooperalex', 'yahoo.com']
# ['plopez', 'yahoo.com']
# ['paul15', 'benson-cohen.org']
# ['donna32', 'young-jimenez.com']
# ['helenphillips', 'patterson.com']
# ['briannajohnson', 'gmail.com']
# ['phillipbailey', 'lawson-ramsey.com']
# ['qcase', 'hotmail.com']
# ['jeffrey31', 'lin.biz']
# ['shane70', 'rodriguez.org']
# ['cory54', 'pena-jackson.net']
# ['hojoseph', 'patton-carter.com']
# ['katrina16', 'gmail.com']
# ['josephlowe', 'bush.com']
# ['matthew89', 'yahoo.com']
# ['destinypierce', 'reed.com']
# ['halejeffrey', 'ballard.com']
# ['solomonsamantha', 'lynch.com']
# ['samanthakent', 'jones.com']
# ['qcole', 'yahoo.com']
# ['kruegerjoseph', 'yahoo.com']
# ['garylozano', 'hotmail.com']
# ['rrush', 'thompson.org']
# ['martin17', 'moore.net']
# ['xwebster', 'yahoo.com']
# ['sally90', 'grant-simmons.com']
# ['hstewart', 'lowe-stephens.com']
# ['kellypace', 'yahoo.com']
# ['ugarcia', 'bennett-freeman.com']
# ['carpentergina', 'gmail.com']
# ['sbanks', 'castro.com']
# ['markgriffin', 'yahoo.com']
# ['efox', 'yahoo.com']
# ['swilliams', 'parker-richard.info']
# ['crystalmoore', 'jackson-williamson.com']
# ['david70', 'gmail.com']
# ['tim53', 'price.com']
# ['taraherrera', 'hotmail.com']
# ['karenhays', 'yahoo.com']
# ['dunnrichard', 'vance.com']
# ['jmeadows', 'gmail.com']
# ['smithnicole', 'hotmail.com']
# ['mckinneyjoanne', 'booth.com']
# ['klopez', 'gmail.com']
# ['lambertchristopher', 'hotmail.com']
# ['harrelljack', 'gmail.com']
# ['amcdonald', 'foster.com']
# ['rfoster', 'jones.biz']
# ['yblake', 'yahoo.com']
# ['mberry', 'wade-myers.biz']
# ['crystalmaxwell', 'yahoo.com']
# ['ryanbaker', 'turner.com']
# ['tnoble', 'miller.net']
# ['christine82', 'wright.com']
# ['russellrivas', 'bennett-matthews.biz']
# ['denniswilliams', 'bowen.biz']
# ['travislee', 'gmail.com']
# ['jamesreyes', 'ballard.biz']
# ['edwin45', 'frank.com']
# ['mark50', 'stevens.org']
# ['nealclaudia', 'brooks.com']
# ['figueroajasmine', 'marquez-salazar.com']
# ['jeffrey41', 'delacruz.com']
# ['robertkim', 'jones.com']
# ['abbottsusan', 'hotmail.com']
# ['kevinmoore', 'henry.biz']
# ['sgonzalez', 'wall.org']
# ['matthew14', 'gonzalez.com']
# ['linda91', 'poole.com']
# ['claytonjessica', 'glenn-brown.com']
# ['gschmidt', 'hotmail.com']
# ['mestrada', 'thomas.com']
# ['hooverjoseph', 'hotmail.com']
# ['sdudley', 'brown-smith.biz']
# ['dorseyrobert', 'delacruz.org']
# ['connie83', 'gmail.com']
# ['powellhenry', 'hotmail.com']
# ['tammy21', 'wallace-shaw.com']
# ['rebeccamelton', 'butler.biz']
# ['georgewalters', 'jones.net']
# ['jordanweaver', 'harmon-vega.net']
# ['anthony56', 'hotmail.com']
# ['tina15', 'myers-smith.info']
# ['elizabeth43', 'frost.org']
# ['shermanrobert', 'mccoy.com']
# ['juangriffin', 'liu.com']
# ['jenniferharris', 'yahoo.com']
# ['gonzalezrachel', 'patton.org']
# ['lynnstacey', 'gmail.com']
# ['cynthia50', 'brooks.net']
# ['tracy48', 'owens.info']
# ['marc21', 'hotmail.com']
# ['andrew24', 'yu-miranda.org']
# ['normanrebecca', 'hotmail.com']
# ['cherylfrancis', 'gmail.com']
# ['shannon41', 'hale.info']
# ['jonesapril', 'gmail.com']
# ['nicole25', 'yahoo.com']
# ['manningjessica', 'gmail.com']
# ['heatherbecker', 'hotmail.com']
# ['steven08', 'gmail.com']
# ['normayoung', 'yahoo.com']
# ['david88', 'carson.com']
# ['williamjohnson', 'hotmail.com']
# ['kcervantes', 'hotmail.com']
# ['amber01', 'hotmail.com']
# ['blewis', 'white-mitchell.info']
# ['sean19', 'hotmail.com']
# ['pwilliams', 'keller.com']
# ['mikayla61', 'romero.com']
# ['rcruz', 'hotmail.com']
# ['nathan96', 'gmail.com']
# ['nathaniel41', 'yahoo.com']
# ['khill', 'hays.biz']
# ['brendasmith', 'yahoo.com']
# ['bwalker', 'gmail.com']
# ['phillipmoore', 'hotmail.com']
# ['cristianbrown', 'townsend.com']
# ['rodgersrobin', 'gmail.com']
# ['hmartinez', 'yahoo.com']
# ['michaelmartin', 'spencer.biz']
# ['opayne', 'hotmail.com']
# ['donalddiaz', 'gmail.com']
# ['bryantlogan', 'wright.com']
# ['trevinomichael', 'gmail.com']
# ['holly69', 'hotmail.com']
# ['rebeccablake', 'wheeler.org']
# ['jennifer54', 'yahoo.com']
# ['tonya37', 'kent.net']
# ['ncummings', 'lawrence.net']
# ['ryanhoward', 'walton-cain.com']
# ['hernandezkristin', 'gmail.com']
# ['matthewwilson', 'gmail.com']
# ['bburgess', 'yahoo.com']
# ['ipatterson', 'yahoo.com']
# ['jennifer46', 'campbell-humphrey.com']
# ['mhull', 'gmail.com']
# ['brenda66', 'gmail.com']
# ['hannah81', 'wood.com']
# ['ewheeler', 'murray-moss.com']
# ['millermelanie', 'yahoo.com']
# ['coxnicole', 'jones.com']
# ['brian90', 'walter.com']
# ['brandon23', 'butler.com']
# ['csoto', 'gmail.com']
# ['richard52', 'yahoo.com']
# ['xcoleman', 'gmail.com']
# ['caseymegan', 'price.org']
# ['danielle53', 'webb.com']
# ['jrice', 'gmail.com']
# ['beckerangela', 'ewing-jackson.net']
# ['emassey', 'gmail.com']
# ['hartjonathan', 'wallace.com']
# ['tsoto', 'orozco-martinez.com']
# ['brittanytorres', 'herrera.com']
# ['angela04', 'yahoo.com']
# ['nicholas55', 'yahoo.com']
# ['reyesjose', 'prince-barber.biz']
# ['angeltorres', 'valenzuela.com']
# ['brittanydonovan', 'cardenas.com']
# ['uorozco', 'scott.info']
# ['joemorrow', 'gmail.com']
# ['qmoran', 'gmail.com']
# ['kayla94', 'hotmail.com']
# ['tinalopez', 'hotmail.com']
# ['timothy33', 'jimenez.com']
# ['todd82', 'gmail.com']
# ['gilesmartin', 'hotmail.com']
# ['seth83', 'bird-cook.info']
# ['noneal', 'blackwell-wood.info']
# ['taylorkimberly', 'hotmail.com']
# ['stacy51', 'mcfarland.com']
# ['sharonbrewer', 'mendoza.com']
# ['erin90', 'yahoo.com']
# ['mooredavid', 'potter.biz']
# ['ythompson', 'rollins.org']
# ['kimlisa', 'yahoo.com']
# ['clarkjohn', 'campbell.com']
# ['qknight', 'gmail.com']
# ['michael08', 'gmail.com']
# ['rossangela', 'yahoo.com']
# ['nicoletaylor', 'rose.com']
# ['kristinmiller', 'yahoo.com']
# ['hilljames', 'hotmail.com']
# ['philipsmith', 'andrews.com']
# ['jason77', 'hotmail.com']
# ['thomaskelsey', 'burns.com']
# ['becky20', 'hotmail.com']
# ['jessetaylor', 'yahoo.com']
# ['yhines', 'grant.com']
# ['luis76', 'gmail.com']
# ['ericahenderson', 'miller.info']
# ['christina19', 'yahoo.com']
# ['pmolina', 'lopez.org']
# ['ramirezrebecca', 'schaefer.info']
# ['emilybarrett', 'gmail.com']
# ['matthewortiz', 'patterson.com']
# ['anncohen', 'gmail.com']
# ['julieevans', 'miller-tran.com']
# ['johnnyfrench', 'jones-benson.com']
# ['samuel77', 'gmail.com']
# ['jenniferschaefer', 'hotmail.com']
# ['thomasdavenport', 'gmail.com']
# ['murphyaustin', 'wong-mueller.com']
# ['marvinharvey', 'soto.com']
# ['nicholasadams', 'gmail.com']
# ['swallace', 'gmail.com']
# ['hartmaneric', 'proctor-young.com']
# ['gabrielthomas', 'gmail.com']
# ['maysabrina', 'palmer.biz']
# ['hernandezandrea', 'yahoo.com']
# ['ymiller', 'yahoo.com']
# ['joycetom', 'farmer.com']
# ['hsimmons', 'hotmail.com']
# ['susanmoore', 'shelton-robinson.com']
# ['vvazquez', 'moran.info']
# ['shelly24', 'mosley.com']
# ['shermanjames', 'hotmail.com']
# ['jason39', 'gmail.com']
# ['brett40', 'bond-brown.biz']
# ['darryl62', 'mitchell.com']
# ['denise14', 'yahoo.com']
# ['maryblankenship', 'orr-bowers.com']
# ['lawsoncourtney', 'scott.com']
# ['riverakenneth', 'hotmail.com']
# ['georgesean', 'gmail.com']
# ['dustinmarshall', 'ortega-smith.info']
# ['tamara02', 'hotmail.com']
# ['evansshawn', 'hotmail.com']
# ['natasha67', 'gmail.com']
# ['duncanmichael', 'hotmail.com']
# ['erik68', 'levine-mcpherson.info']
# ['shelby42', 'jenkins.net']
# ['smoore', 'yahoo.com']
# ['jessica67', 'martin-alexander.com']
# ['younganne', 'chaney.com']
# ['ylawson', 'parks-hicks.org']
# ['victoria04', 'hotmail.com']
# ['douglas31', 'barber-mccormick.com']
# ['kyle09', 'li.info']
# ['ehughes', 'yahoo.com']
# ['theresa29', 'gmail.com']
# ['richard05', 'yahoo.com']
# ['victoria44', 'beasley-moore.net']
# ['barbarareed', 'hotmail.com']
# ['thompsonvanessa', 'yahoo.com']
# ['goodwinmary', 'cunningham.com']
# ['melissanguyen', 'hunt-davis.com']
# ['khall', 'gmail.com']
# ['jacksonana', 'frey.com']
# ['ztaylor', 'leonard.com']
# ['biancabarton', 'coleman.org']
# ['jennifermartinez', 'gmail.com']
# ['ashleybradley', 'hotmail.com']
# ['davisdiane', 'yahoo.com']
# ['obriencynthia', 'huerta.org']
# ['xdyer', 'hotmail.com']
# ['trich', 'yahoo.com']
# ['ljackson', 'gmail.com']
# ['zmorrow', 'schneider.org']
# ['tmorgan', 'johnson.org']
# ['nmendoza', 'edwards.org']
# ['douglasmontoya', 'reynolds.info']
# ['patriciacarter', 'owens.info']
# ['lyonsthomas', 'alvarez-klein.net']
# ['lsanchez', 'gmail.com']
# ['michael65', 'orr-frank.com']
# ['jacksonalexandra', 'yahoo.com']
# ['ambermeyer', 'yahoo.com']
# ['peckjoshua', 'petersen.com']
# ['jamesrodriguez', 'gmail.com']
# ['michael73', 'robles-garza.org']
# ['caldwelljoseph', 'gmail.com']
# ['olivia32', 'gmail.com']
# ['colonfernando', 'rogers-craig.com']
# ['brittanyellis', 'aguilar.org']
# ['kimberlycurtis', 'gmail.com']
# ['markreed', 'yahoo.com']
# ['anthonycohen', 'hebert-rodriguez.com']
# ['leahrichard', 'yahoo.com']
# ['thomasbell', 'lopez-mueller.com']
# ['nicole99', 'gmail.com']
# ['lmatthews', 'yahoo.com']
# ['jeffreymcguire', 'hotmail.com']
# ['mortonkimberly', 'gmail.com']
# ['odonnellbrian', 'hotmail.com']
# ['staylor', 'davis.com']
# ['matthewalvarez', 'yahoo.com']
# ['deanna23', 'yahoo.com']
# ['mcbridejason', 'hotmail.com']
# ['wtownsend', 'gmail.com']
# ['bryce20', 'hotmail.com']
# ['ojohnson', 'jones.com']
# ['dyergregory', 'hall.net']
# ['greyes', 'davis.com']
# ['whitehailey', 'hotmail.com']
# ['johndunn', 'gmail.com']
# ['younglinda', 'knapp.com']
# ['kenneth84', 'gmail.com']
# ['danielharvey', 'hotmail.com']
# ['mcconnellangela', 'morris-martin.com']
# ['dylanperez', 'barton.com']
# ['stephaniecoleman', 'hotmail.com']
# ['foxshawn', 'yahoo.com']
# ['williamsamber', 'mcintosh-price.com']
# ['everettmaria', 'gonzalez-lee.com']
# ['psullivan', 'hill-hood.com']
# ['geraldwhite', 'arnold.com']
# ['yhopkins', 'yahoo.com']
# ['johnsonlaura', 'hotmail.com']
# ['parkerfrye', 'gmail.com']
# ['susanshepard', 'hotmail.com']
# ['tuckeramber', 'yahoo.com']
# ['aprillee', 'gmail.com']
# ['zacharydavis', 'miller.com']
# ['crawfordcarl', 'gmail.com']
# ['webbthomas', 'hotmail.com']
# ['stevencardenas', 'strong.com']
# ['tracieclark', 'ross.com']
# ['sara23', 'brown-burns.org']
# ['heididean', 'gmail.com']
# ['rroberts', 'larson.com']
# ['batescasey', 'gmail.com']
# ['christyhanson', 'yahoo.com']
# ['qvincent', 'ramsey.com']
# ['torrestimothy', 'hotmail.com']
# ['melissamartin', 'steele.com']
# ['george41', 'gmail.com']
# ['kmarshall', 'parker.net']
# ['emily52', 'george-ramirez.com']
# ['kingelizabeth', 'matthews-nelson.net']
# ['fernandezjoshua', 'gmail.com']
# ['jessica94', 'white.info']
# ['henrytaylor', 'yahoo.com']
# ['barbarajames', 'kline.info']
# ['glennbrett', 'hotmail.com']
# ['chad13', 'white.com']
# ['carl94', 'hotmail.com']
# ['kelleyemily', 'williams.com']
# ['foxkelsey', 'hotmail.com']
# ['bphillips', 'leach-brown.com']
# ['rosssmith', 'colon-hawkins.com']
# ['erikramirez', 'molina-price.com']
# ['jasonsanchez', 'hotmail.com']
# ['dennis14', 'waters.info']
# ['tpope', 'lynch-huber.org']
# ['strongtony', 'hotmail.com']
# ['ross74', 'gmail.com']
# ['woodscarrie', 'gmail.com']
# ['abruce', 'hotmail.com']
# ['bphillips', 'arroyo.net']
# ['nicholasgomez', 'washington-lee.net']
# ['marygonzalez', 'smith.org']
# ['floresjames', 'ross.com']
# ['shermanelizabeth', 'bowers.com']
# ['daniellekeller', 'vargas.org']
# ['jeffrey61', 'gmail.com']
# ['humphreysarah', 'berry.com']
# ['xcurry', 'williams-hayes.info']
# ['jacqueline13', 'hotmail.com']
# ['mark75', 'white-myers.biz']
# ['scott35', 'yahoo.com']
# ['kristin66', 'yahoo.com']
# ['dhuff', 'hotmail.com']
# ['oramirez', 'ayers.com']
# ['lvazquez', 'fernandez.com']
# ['jharris', 'blevins.com']
# ['ashley48', 'floyd-nelson.com']
# ['velazquezbrittney', 'ryan.biz']
# ['eguerrero', 'snyder.info']
# ['guerrerokayla', 'rodriguez-matthews.info']
# ['matthewbarr', 'yahoo.com']
# ['jessica63', 'delgado-stewart.info']
# ['sandra16', 'morton.com']
# ['hwest', 'woods.com']
# ['heather42', 'yahoo.com']
# ['wellis', 'kennedy.com']
# ['bowersmatthew', 'nunez-acosta.org']
# ['briangriffin', 'morris-roberts.info']
# ['bfrye', 'russell.biz']
# ['eallen', 'scott.com']
# ['tanya81', 'hotmail.com']
# ['ramirezapril', 'gmail.com']
# ['jim33', 'montes-schmidt.com']
# ['dawnmcdonald', 'hess-mcgee.com']
# ['matthewwilson', 'gmail.com']
# ['jharrison', 'woods.com']
# ['vali', 'gmail.com']
# ['kking', 'jordan.com']
# ['twood', 'williams.biz']
# ['tammytaylor', 'ortega.com']
# ['wagnerjasmine', 'lawson.com']
# ['chelsea50', 'gmail.com']
# ['sdunn', 'hotmail.com']
# ['john00', 'gmail.com']
# ['afrancis', 'holt-garcia.net']
# ['psteele', 'gmail.com']
# ['jenniferspears', 'austin.com']
# ['thomasglover', 'cook.com']
# ['acook', 'carter-williams.org']
# ['sandersmia', 'morales.com']
# ['tlewis', 'gmail.com']
# ['bcampbell', 'yahoo.com']
# ['xbrock', 'perry-ayala.com']
# ['kathryn74', 'brown.org']
# ['hillsara', 'hotmail.com']
# ['xdavis', 'cooper-gonzales.net']
# ['allison02', 'hotmail.com']
# ['jenniferfaulkner', 'gmail.com']
# ['daynatalie', 'hotmail.com']
# ['angela05', 'ford.com']
# ['welchbrandon', 'smith-smith.com']
# ['greendana', 'yahoo.com']
# ['tritter', 'gmail.com']
# ['bpage', 'gonzalez.com']
# ['angelaalvarez', 'freeman-evans.info']
# ['cherylbailey', 'miller-curtis.biz']
# ['matthewallen', 'hotmail.com']
# ['keithhurst', 'andrews.com']
# ['fieldsrichard', 'brown.org']
# ['audrey47', 'johnson.com']
# ['jerryreeves', 'gmail.com']
# ['christophersharp', 'guzman.com']
# ['thomas39', 'conner.info']
# ['vgray', 'schmidt.info']
# ['ericpittman', 'hotmail.com']
# ['thompsonlisa', 'hernandez.com']
# ['matthewnichols', 'yahoo.com']
# ['hollanddenise', 'hernandez.com']
# ['howardsusan', 'gmail.com']
# ['christopher56', 'tucker.com']
# ['xfreeman', 'fernandez-parker.com']
# ['floresdawn', 'hotmail.com']
# ['nwatkins', 'yahoo.com']
# ['william98', 'gmail.com']
# ['garciacandace', 'gmail.com']
# ['diazkristin', 'yahoo.com']
# ['choiallen', 'hotmail.com']
# ['fishercourtney', 'patterson.org']
# ['deantimothy', 'hawkins.com']
# ['glennglenn', 'burns-williams.net']
# ['melissa08', 'hotmail.com']
# ['lvelez', 'hotmail.com']
# ['ggarza', 'vega-ellis.org']
# ['kelly70', 'giles.com']
# ['caitlinmorgan', 'gmail.com']
# ['tylerscott', 'ortiz.com']
# ['herringmichelle', 'hotmail.com']
# ['lopezrebecca', 'gmail.com']
# ['megan03', 'grant.com']
# ['jenningstimothy', 'gmail.com']
# ['josephreyes', 'howard-cook.org']
# ['nthornton', 'yahoo.com']
# ['caitlinmurray', 'novak.org']
# ['valerielarsen', 'hotmail.com']
# ['christinaparker', 'yahoo.com']
# ['ryanconnor', 'hotmail.com']
# ['davisrobert', 'santos.com']
# ['udaniel', 'martinez.biz']
# ['nblack', 'yahoo.com']
# ['john54', 'hodges.com']
# ['lpham', 'hotmail.com']
# ['logancarrie', 'marquez.com']
# ['dmartinez', 'johnson.biz']
# ['shermanjeffrey', 'hotmail.com']
# ['samuelward', 'hotmail.com']
# ['kimberlyzavala', 'massey.net']
# ['jamesdyer', 'ellis-young.info']
# ['zvega', 'gmail.com']
# ['brandonrichards', 'shelton.com']
# ['johnhuang', 'gmail.com']
# ['julie99', 'yahoo.com']
# ['martinezisaiah', 'williams.com']
# ['danielleharris', 'young.com']
# ['smithmackenzie', 'gmail.com']
# ['patricianorman', 'simmons-zimmerman.com']
# ['thomas55', 'gmail.com']
# ['annespence', 'matthews-herman.info']
# ['ashleyfloyd', 'yahoo.com']
# ['njones', 'pruitt-peck.org']
# ['kimberlymills', 'hotmail.com']
# ['williamskatelyn', 'gmail.com']
# ['montgomerysteven', 'cohen-bender.biz']
# ['kvaldez', 'williams.biz']
# ['tyler40', 'gmail.com']
# ['hnorman', 'hotmail.com']
# ['stephanie52', 'hicks-warner.info']
# ['rsanders', 'walker.com']
# ['brandy22', 'hotmail.com']
# ['robertsruth', 'huynh-stanton.info']
# ['reneecline', 'cole.biz']
# ['rebeccamcdonald', 'hotmail.com']
# ['paul10', 'gmail.com']
# ['connorgill', 'collins.org']
# ['johnsonjerry', 'santiago.com']
# ['timothy07', 'jones-rodriguez.net']
# ['brianphillips', 'mitchell.biz']
# ['hlambert', 'davis-lewis.com']
# ['scottmartin', 'yahoo.com']
# ['hannah20', 'smith.com']
# ['olsonjeffrey', 'yahoo.com']
# ['allenemily', 'williams.com']
# ['tylergary', 'tran.info']
# ['wnovak', 'yahoo.com']
# ['vincent02', 'johnson.org']
# ['alexanderelliott', 'martin-white.com']
# ['kellyamanda', 'gmail.com']
# ['hinesamanda', 'mcmillan.net']
# ['thomas51', 'wilcox-parker.org']
# ['kholloway', 'hotmail.com']
# ['jackjones', 'jackson.com']
# ['mark00', 'foster-drake.com']
# ['cgibson', 'hansen.com']
# ['mkhan', 'gmail.com']
# ['richardwhite', 'mills-sutton.com']
# ['katherine00', 'smith.info']
# ['karen14', 'scott-kaufman.com']
# ['karenbartlett', 'gmail.com']
# ['csmith', 'hall-ochoa.com']
# ['rcox', 'yahoo.com']
# ['eugene89', 'jones-clark.com']
# ['nicholasmoore', 'anderson-rodriguez.org']
# ['jonesjames', 'yahoo.com']
# ['paulamarshall', 'stout.org']
# ['robert34', 'yates.com']
# ['alison17', 'hotmail.com']
# ['victorallen', 'meza.info']
# ['efrederick', 'miller.info']
# ['sarah50', 'webster.net']
# ['harrisjonathan', 'hotmail.com']
# ['fmay', 'edwards-cooper.com']
# ['wagnermelissa', 'yahoo.com']
# ['amandarogers', 'gmail.com']
# ['rodriguezkristin', 'hotmail.com']
# ['ereed', 'gmail.com']
# ['charles52', 'hotmail.com']
# ['jasonjohnson', 'hotmail.com']
# ['danieldawson', 'yahoo.com']
# ['kenneth72', 'morris.com']
# ['carol62', 'moore.com']
# ['dannyclark', 'hebert.org']
# ['larsonmatthew', 'gmail.com']
# ['maryharper', 'phillips.org']
# ['suzanneyoung', 'hotmail.com']
# ['martinezamanda', 'davis.net']
# ['samantha42', 'ferguson-ross.com']
# ['courtneyalvarado', 'sellers.com']
# ['tsantos', 'young.com']
# ['christopher31', 'hotmail.com']
# ['katherine43', 'gmail.com']
# ['barneschristina', 'buckley.com']
# ['tbrown', 'bonilla.info']
# ['mark26', 'grimes.com']
# ['kathleen98', 'gmail.com']
# ['sandovalheather', 'giles.info']
# ['wclark', 'gmail.com']
# ['matthewgutierrez', 'martinez.com']
# ['athompson', 'gmail.com']
# ['jonesvictoria', 'wade.org']
# ['seth87', 'willis.com']
# ['duncanross', 'torres-meyer.biz']
# ['amberespinoza', 'taylor.info']
# ['melinda28', 'hotmail.com']
# ['brian96', 'yahoo.com']
# ['oneillcassandra', 'ramirez.com']
# ['robertagreene', 'rice.com']
# ['cmoore', 'larsen.com']
# ['lisahurst', 'yahoo.com']
# ['cburnett', 'yahoo.com']
# ['curtismcconnell', 'marshall.info']
# ['samuel65', 'gmail.com']
# ['powerslaura', 'kim.com']
# ['travis90', 'yahoo.com']
# ['joneslisa', 'gmail.com']
# ['robinsonjamie', 'pierce-calhoun.com']
# ['fmcbride', 'yahoo.com']
# ['lynchrichard', 'duffy-murray.com']
# ['tsmith', 'smith-waters.info']
# ['smithnathan', 'rosario.com']
# ['johnstephens', 'hotmail.com']
# ['william88', 'torres-johnson.com']
# ['cassandra05', 'yahoo.com']
# ['ramoschristopher', 'calhoun.biz']
# ['zgreen', 'yahoo.com']
# ['robert72', 'byrd.info']
# ['chodges', 'watts-schmidt.org']
# ['smithjose', 'carpenter.com']
# ['michelleking', 'yahoo.com']
# ['lindaortiz', 'hotmail.com']
# ['rperez', 'hall.com']
# ['paula86', 'yahoo.com']
# ['lwalker', 'roach-alexander.com']
# ['vmaxwell', 'vargas-peters.com']
# ['meyermichael', 'taylor.com']
# ['kimberlylewis', 'williams.biz']
# ['steven18', 'yahoo.com']
# ['leonard65', 'lewis-lloyd.com']
# ['yangjohn', 'warren.com']
# ['david10', 'dodson-warner.com']
# ['sarawhite', 'stephenson-stephens.biz']
# ['andreamatthews', 'patton.com']
# ['browncorey', 'gmail.com']
# ['umoreno', 'davis-rubio.info']
# ['brollins', 'yahoo.com']
# ['nestrada', 'sanchez-fisher.com']
# ['bjohnson', 'hotmail.com']
# ['allengerald', 'hotmail.com']
# ['jason73', 'hotmail.com']
# ['brooke78', 'gonzales.com']
# ['thomaspaul', 'gmail.com']
# ['perezlisa', 'gmail.com']
# ['tracey53', 'sanchez.com']
# ['marshallerin', 'hotmail.com']
# ['jay46', 'hubbard.info']
# ['wmedina', 'ramirez.org']
# ['lgomez', 'york-bird.com']
# ['samuellambert', 'yahoo.com']
# ['vdoyle', 'wise-olson.com']
# ['welchmatthew', 'yahoo.com']
# ['hodgewilliam', 'gmail.com']
# ['larry87', 'hotmail.com']
# ['ritterkatherine', 'gmail.com']
# ['pricejeremy', 'rodriguez.info']
# ['kimberly60', 'gmail.com']
# ['lynnnatasha', 'moore.com']
# ['janetquinn', 'jimenez.net']
# ['jeffcoffey', 'hotmail.com']
# ['espinozajohn', 'yahoo.com']
# ['eyoung', 'gmail.com']
# ['ninabrooks', 'hotmail.com']
# ['carla99', 'woods.com']
# ['timothylee', 'yahoo.com']
# ['jennifer58', 'hotmail.com']
# ['nguyenlauren', 'martin.net']
# ['trevor52', 'buchanan-anderson.com']
# ['walkerchristopher', 'yahoo.com']
# ['matthew49', 'yahoo.com']
# ['millerscott', 'stevenson.biz']
# ['mcdonaldlacey', 'hotmail.com']
# ['corymyers', 'gmail.com']
# ['calebrussell', 'ware-odom.com']
# ['debra82', 'flores-flowers.com']
# ['whernandez', 'hotmail.com']
# ['davidjoseph', 'yahoo.com']
# ['ortizmitchell', 'yahoo.com']
# ['dustinchan', 'wheeler.com']
# ['andrew81', 'cunningham-barrett.net']
# ['jason81', 'king.biz']
# ['benjaminwilliams', 'walls.com']
# ['cookedavid', 'clayton-davidson.com']
# ['vmcdaniel', 'hotmail.com']
# ['michaelevans', 'gmail.com']
# ['srose', 'gmail.com']
# ['gdiaz', 'gmail.com']
# ['kathryn87', 'yahoo.com']
# ['tunderwood', 'dunn-edwards.com']
# ['solisnatasha', 'yahoo.com']
# ['cantulance', 'reyes.com']
# ['michael63', 'hill.com']
# ['msmith', 'bailey.biz']
# ['smithrandy', 'yahoo.com']
# ['jameswatson', 'smith.com']
# ['elizabeth78', 'hotmail.com']
# ['contrerasvalerie', 'morales.biz']
# ['coreyroberts', 'gmail.com']
# ['holly01', 'bowen.net']
# ['farrelldavid', 'james-blake.biz']
# ['chaddodson', 'mills.com']
# ['peterwade', 'elliott-watson.com']
# ['ibrown', 'burgess.info']
# ['mcmillankyle', 'yahoo.com']
# ['jamesreeves', 'hotmail.com']
# ['nicole62', 'ramirez-diaz.com']
# ['ypayne', 'hudson.com']
# ['owhite', 'hester.com']
# ['samuelyoder', 'valenzuela.org']
# ['gtaylor', 'humphrey.biz']
# ['dustinmooney', 'gmail.com']
# ['kirbyloretta', 'michael.com']
# ['johnsonnancy', 'miller.org']
# ['camachotiffany', 'yahoo.com']
# ['tthomas', 'santiago.org']
# ['sylviamorgan', 'hotmail.com']
# ['amanda05', 'gmail.com']
# ['douglas47', 'yahoo.com']
# ['ethomas', 'hotmail.com']
# ['michellemcgrath', 'gmail.com']
# ['linda32', 'yahoo.com']
# ['perezdavid', 'hotmail.com']
# ['amyfernandez', 'yahoo.com']
# ['bsmith', 'gmail.com']
# ['ebaker', 'gmail.com']
# ['oblack', 'hotmail.com']
# ['butlerkimberly', 'ho-palmer.com']
# ['crosbybrenda', 'stuart.com']
# ['dhicks', 'yahoo.com']
# ['smithkevin', 'hotmail.com']
# ['lisa88', 'hotmail.com']
# ['holly47', 'white-howard.com']
# ['jennifer43', 'yahoo.com']
# ['unorton', 'ward-ruiz.org']
# ['tswanson', 'macias-williams.net']
# ['jenny54', 'gmail.com']
# ['pamelarodriguez', 'leblanc-price.info']
# ['rodney34', 'franco.biz']
# ['nelsonethan', 'morales.com']
# ['matthewpreston', 'camacho.net']
# ['jerryramirez', 'hotmail.com']
# ['cjones', 'ball.com']
# ['shearobert', 'schultz.biz']
# ['paulaellis', 'mosley.org']
# ['coopercandice', 'yahoo.com']
# ['david88', 'hotmail.com']
# ['gjimenez', 'allen.biz']
# ['john72', 'collins-johnson.biz']
# ['dana06', 'decker-buchanan.com']
# ['ryanjoyce', 'taylor.com']
# ['ashleyjohnson', 'todd.net']
# ['charles57', 'martinez-anderson.com']
# ['jonathanmarks', 'wheeler-goodman.com']
# ['christopher39', 'hotmail.com']
# ['teresaross', 'smith-calhoun.com']
# ['terricarter', 'yahoo.com']
# ['jkelley', 'williams-levy.com']
# ['trodriguez', 'kennedy.org']
# ['palmererin', 'noble-spencer.info']
# ['holmeskelly', 'hotmail.com']
# ['lisamckenzie', 'bailey.org']
# ['brownmckenzie', 'kline.com']
# ['april04', 'price-wilson.com']
# ['william26', 'church.net']
# ['diazjohn', 'yahoo.com']
# ['jonesemily', 'carter.com']
# ['bassapril', 'green-rodgers.com']
# ['javierdennis', 'estrada.com']
# ['nlambert', 'love-sanchez.net']
# ['diazedward', 'owen.com']
# ['mollymerritt', 'hotmail.com']
# ['jasonhall', 'yahoo.com']
# ['qcabrera', 'gmail.com']
# ['peter39', 'nguyen-wright.info']
# ['patriciareilly', 'smith.com']
# ['tmason', 'pope.info']
# ['julie05', 'taylor-bishop.com']
# ['savannah22', 'mccoy.biz']
# ['jonathan99', 'gmail.com']
# ['cantuheather', 'hotmail.com']
# ['amanda15', 'hunter-oconnell.net']
# ['sarahmartinez', 'yahoo.com']
# ['darin35', 'gmail.com']
# ['tmaddox', 'gmail.com']
# ['melissagardner', 'gmail.com']
# ['thompsonkim', 'carson.com']
# ['melvinhanna', 'williams.com']
# ['gaguilar', 'hotmail.com']
# ['steven29', 'yahoo.com']
# ['armstrongtamara', 'yahoo.com']
# ['goodwinisaiah', 'castro.com']
# ['jessicadavis', 'crawford.com']
# ['tylermorrison', 'yahoo.com']
# ['brandon66', 'yahoo.com']
# ['michael62', 'yahoo.com']
# ['jamie04', 'yahoo.com']
# ['herrerathomas', 'yahoo.com']
# ['jamesnichols', 'atkins.com']
# ['ruth94', 'gmail.com']
# ['sanchezkaitlyn', 'howell-nelson.net']
# ['qsantos', 'brown.com']
# ['cookthomas', 'fisher.com']
# ['jamescortez', 'anthony-guerra.com']
# ['elizabethgarcia', 'hotmail.com']
# ['aprilbrewer', 'palmer.biz']
# ['justin91', 'yahoo.com']
# ['aconway', 'krueger-walker.com']
# ['barbarajensen', 'gmail.com']
# ['williamchapman', 'gmail.com']
# ['mcdonaldholly', 'andrews-simpson.biz']
# ['stevenduran', 'mccall.com']
# ['jonathan78', 'foster.com']
# ['dawn76', 'hotmail.com']
# ['tsanchez', 'hotmail.com']
# ['ewilliams', 'gmail.com']
# ['melissawhite', 'hotmail.com']
# ['johnsonpaula', 'gmail.com']
# ['wcharles', 'yahoo.com']
# ['lisafischer', 'yahoo.com']
# ['yhunt', 'gmail.com']
# ['hharmon', 'collins-cole.info']
# ['vortega', 'thomas.com']
# ['ashleyobrien', 'hotmail.com']
# ['tammytrujillo', 'reynolds.com']
# ['connorgamble', 'rivers.com']
# ['sbutler', 'wilcox.com']
# ['joshuaherrera', 'hotmail.com']
# ['ostevens', 'hotmail.com']
# ['patricksmith', 'butler.org']
# ['richard69', 'yahoo.com']
# ['daniel93', 'sims.com']
# ['tiffanyhammond', 'martin.com']
# ['nrobertson', 'yahoo.com']
# ['vruiz', 'hotmail.com']
# ['allen91', 'hotmail.com']
# ['jennifer35', 'hotmail.com']
# ['ljohnson', 'hotmail.com']
# ['morrowgina', 'yahoo.com']
# ['lewiscolin', 'hotmail.com']
# ['lori98', 'collier.org']
# ['fjimenez', 'garcia-contreras.com']
# ['matthew62', 'gmail.com']
# ['rachaelmcknight', 'ellison.com']
# ['anna59', 'hotmail.com']
# ['emilyscott', 'potter-kane.info']
# ['strongmichael', 'hotmail.com']
# ['diane63', 'burke-perez.org']
# ['fowlerstephanie', 'gill.com']
# ['bvillanueva', 'yahoo.com']
# ['campbellcarolyn', 'guerrero-huynh.com']
# ['llevine', 'yahoo.com']
# ['hmorgan', 'jackson.org']
# ['barronlaura', 'yahoo.com']
# ['jeffreygonzalez', 'gmail.com']
# ['james82', 'ballard.com']
# ['robert58', 'white.com']
# ['valerie61', 'mccarthy-baxter.info']
# ['middletonmichele', 'hotmail.com']
# ['combsricky', 'jones.info']
# ['reneewagner', 'yahoo.com']
# ['karen22', 'ramirez.net']
# ['crogers', 'yahoo.com']
# ['noah53', 'castaneda-evans.com']
# ['zcoleman', 'yahoo.com']
# ['bbrown', 'richmond.com']
# ['ugross', 'montgomery-miller.org']
# ['garybradley', 'mcdonald.org']
# ['jamesyoung', 'yahoo.com']
# ['bairddavid', 'tucker.net']
# ['jocelyn36', 'gmail.com']
# ['pricesandra', 'lawrence.net']
# ['joshuarice', 'wright.info']
# ['hbeasley', 'anderson-herrera.biz']
# ['paula12', 'gmail.com']
# ['erika06', 'harper-mcmillan.com']
# ['karen97', 'gmail.com']
# ['guzmanjohn', 'yahoo.com']
# ['michaellopez', 'trujillo.info']
# ['mlucas', 'gmail.com']
# ['tsanchez', 'gmail.com']
# ['garciarussell', 'newman.net']
# ['steven87', 'richmond.com']
# ['williamsangela', 'richardson-adams.com']
# ['rebeccamarshall', 'richmond.com']
# ['mullinsaaron', 'hotmail.com']
# ['peterserin', 'reed-johnston.com']
# ['chughes', 'camacho.com']
# ['williamsdaniel', 'shaw.com']
# ['nsimmons', 'harper-smith.biz']
# ['tinapatrick', 'carter-york.com']
# ['mackenziewilliams', 'ford-martinez.com']
# ['teresaadkins', 'jones.com']
# ['olsonjohn', 'hotmail.com']
# ['jvalenzuela', 'vang.net']
# ['roypeter', 'gmail.com']
# ['mary54', 'hotmail.com']
# ['matthewwagner', 'evans.info']
# ['gjackson', 'yahoo.com']
# ['rmonroe', 'lopez-taylor.org']
# ['fritzalyssa', 'gmail.com']
# ['smcdaniel', 'powers.com']
# ['santanathomas', 'palmer.com']
# ['william05', 'yahoo.com']
# ['diazcory', 'lee.com']
# ['kevin03', 'gmail.com']
# ['coreywyatt', 'gmail.com']
# ['kevinbrady', 'yahoo.com']
# ['simssabrina', 'wilkins-campos.com']
# ['william63', 'walter-scott.net']
# ['mclaughlindeborah', 'lewis.com']
# ['margaret87', 'yahoo.com']
# ['patrick71', 'gmail.com']
# ['dannymills', 'yahoo.com']
# ['anne59', 'santana-perez.org']
# ['christina12', 'smith.com']
# ['william06', 'lee-moore.com']
# ['dean21', 'hotmail.com']
# ['dmiller', 'mendoza.com']
# ['matthew41', 'sexton-lee.com']
# ['baxtermary', 'callahan-robinson.com']
# ['travis15', 'garcia.com']
# ['umoreno', 'yahoo.com']
# ['georgesmith', 'gmail.com']
# ['odawson', 'yahoo.com']
# ['keith24', 'gmail.com']
# ['juarezcharles', 'finley-snyder.net']
# ['ortizamy', 'yahoo.com']
# ['joseph18', 'byrd-williams.net']
# ['sevans', 'jackson.com']
# ['stevekrueger', 'yahoo.com']
# ['bethtaylor', 'rhodes.info']
# ['laura41', 'carr.com']
# ['yleonard', 'lopez.com']
# ['kimberlymartinez', 'yahoo.com']
# ['hebertheather', 'thornton-powell.info']
# ['kristinmorgan', 'rich.biz']
# ['charlesfranco', 'hotmail.com']
# ['nicholas02', 'hotmail.com']
# ['vcarter', 'yahoo.com']
# ['qharrison', 'gmail.com']
# ['mckinneyrachel', 'lee.com']
# ['jeremyrangel', 'washington.org']
# ['nking', 'yahoo.com']
# ['evanstamara', 'edwards.com']
# ['nskinner', 'gmail.com']
# ['vmartinez', 'willis-wilson.com']
# ['okirk', 'valencia.com']
# ['ztrevino', 'martinez.com']
# ['henrybooth', 'rodriguez.com']
# ['courtneytaylor', 'henry-marquez.net']
# ['cynthia83', 'brown.com']
# ['rclements', 'yahoo.com']
# ['sheppardjames', 'gonzalez.com']
# ['amy28', 'hotmail.com']
# ['tristan10', 'yahoo.com']
# ['zamorajean', 'hotmail.com']
# ['paul57', 'gmail.com']
# ['jason94', 'warren-campbell.com']
# ['kimberly50', 'yahoo.com']
# ['jennifermora', 'vance-prince.com']
# ['zmiranda', 'fisher.com']
# ['natashadavis', 'hotmail.com']
# ['watkinsbrandon', 'gonzalez.info']
# ['keithlowe', 'yahoo.com']
# ['uthomas', 'davis.com']
# ['lovejoe', 'west.com']
# ['shelly20', 'gmail.com']
# ['whitneycarpenter', 'smith.net']
# ...
# ['brandon95', 'hotmail.com']
# ['williamssabrina', 'hotmail.com']
# ['ibrown', 'hotmail.com']
# ['bryan85', 'hall-harris.biz']
# ['crystal72', 'yahoo.com']
# ['ojordan', 'coleman.com']
# ['mjackson', 'meyers.com']
# ['denise74', 'jackson.org']
# ['ohill', 'hotmail.com']
# ['navarromark', 'gmail.com']
# ['vwest', 'yahoo.com']
# ['gbaxter', 'fuentes-grant.com']
# ['albert99', 'hotmail.com']
# ['andrew58', 'bird.com']
# ['vadams', 'richard.com']
# ['pamelacole', 'buchanan-brown.com']
# ['jasonlarson', 'yahoo.com']
# ['amymiller', 'cook-coffey.com']
# ['nelsonjason', 'yahoo.com']
# ['morganstephen', 'gmail.com']
# ['masseyscott', 'yahoo.com']
# ['kyliehernandez', 'yahoo.com']
# ['esmith', 'hotmail.com']
# ['kylehuffman', 'orr.org']
# ['stevenjones', 'hotmail.com']
# ['amy27', 'gmail.com']
# ['petersjamie', 'gmail.com']
# ['relliott', 'kent-brown.info']
# ['ureynolds', 'maxwell.com']
# ['johnnyfletcher', 'gmail.com']
# ['craig05', 'gmail.com']
# ['rlopez', 'hotmail.com']
# ['uthomas', 'gutierrez-barber.com']
# ['caroltaylor', 'stone.com']
# ['edwardwashington', 'saunders-mahoney.info']
# ['jlyons', 'hotmail.com']
# ['franksmith', 'gmail.com']
# ['butlermiranda', 'gmail.com']
# ['abigail26', 'gmail.com']
# ['merrittkevin', 'gmail.com']
# ['emilymoore', 'short.org']
# ['robertcampbell', 'gonzalez.biz']
# ['amy68', 'fisher.biz']
# ['phernandez', 'gmail.com']
# ['robertsrobert', 'rice.com']
# ['hensleyedwin', 'gould.com']
# ['jeffrey26', 'hess-mccormick.com']
# ['padillaamy', 'evans.net']
# ['davidarnold', 'gmail.com']
# ['wjordan', 'marshall.org']
# ['alexander89', 'armstrong.org']
# ['michellemarshall', 'brennan.com']
# ['myersthomas', 'hotmail.com']
# ['kentkhan', 'hotmail.com']
# ['harold49', 'grant.com']
# ['chasefloyd', 'shaw.com']
# ['mdavis', 'howell-reed.info']
# ['michael21', 'yahoo.com']
# ['rosskenneth', 'hotmail.com']
# ['wsmith', 'olson-henderson.org']
# ['ariellane', 'gmail.com']
# ['rebekah36', 'gmail.com']
# ['garycarter', 'foster.net']
# ['xfernandez', 'yahoo.com']
# ['oturner', 'hotmail.com']
# ['christian91', 'miller.biz']
# ['jacob22', 'rodriguez.net']
# ['jeremyporter', 'yahoo.com']
# ['sabrinacoleman', 'yahoo.com']
# ['ericburns', 'yahoo.com']
# ['rhodesian', 'gmail.com']
# ['andrewpatterson', 'gmail.com']
# ['juliaphillips', 'mason-wilson.com']
# ['lauramartin', 'gmail.com']
# ['evansgary', 'french-pittman.org']
# ['coxkelly', 'lee-hicks.net']
# ['millermichael', 'reynolds.com']
# ['nicolepearson', 'beck.biz']
# ['thompsonpaul', 'ramirez-watson.org']
# ['franklinmarissa', 'yahoo.com']
# ['icarey', 'gibson.com']
# ['qrandall', 'mccann.net']
# ['caldwelldylan', 'mills-oliver.com']
# ['dwong', 'yahoo.com']
# ['christopher85', 'garza.com']
# ['karabeck', 'hotmail.com']
# ['kristen69', 'hotmail.com']
# ['adavis', 'jones.org']
# ['uthomas', 'yahoo.com']
# ['wfrey', 'martinez-mendoza.com']
# ['suzannemoore', 'green.com']
# ['richardsoto', 'ramsey.org']
# ['lavila', 'hotmail.com']
# ['gespinoza', 'gmail.com']
# ['lisa87', 'yahoo.com']
# ['alyssa61', 'gmail.com']
# ['steven08', 'hotmail.com']
# ['elizabethtaylor', 'gmail.com']
# ['alfredmatthews', 'morris.com']
# ['jenniferprince', 'livingston.com']
# ['danielwall', 'yahoo.com']
# ['wclark', 'yahoo.com']
# ['martin01', 'kemp.com']
# ['staceymoore', 'hotmail.com']
# ['michael76', 'yahoo.com']
# ['matthewroberts', 'yahoo.com']
# ['nrogers', 'welch.com']
# ['yross', 'townsend.org']
# ['adammaldonado', 'hotmail.com']
# ['gcarr', 'gmail.com']
# ['carolinewilliams', 'frye.com']
# ['chris77', 'byrd.com']
# ['ypark', 'gmail.com']
# ['ahuang', 'walters.com']
# ['xlee', 'gmail.com']
# ['warebrittany', 'johnson.com']
# ['samanthahammond', 'gmail.com']
# ['joshualowe', 'weiss.com']
# ['russellsalazar', 'graves-hunter.com']
# ['raymond65', 'hotmail.com']
# ['klindsey', 'morales.org']
# ['fergusonvernon', 'gmail.com']
# ['fwright', 'watson.biz']
# ['joethomas', 'brown.net']
# ['smithcarol', 'bonilla.com']
# ['smithsean', 'jordan-webster.com']
# ['lydia92', 'hotmail.com']
# ['tina05', 'yahoo.com']
# ['patriciacarrillo', 'harmon.com']
# ['briannariley', 'dixon.com']
# ['pauldavis', 'hotmail.com']
# ['olsonscott', 'yahoo.com']
# ['swilson', 'hotmail.com']
# ['joseph41', 'sellers.net']
# ['markreed', 'lutz-silva.net']
# ['tmoran', 'gmail.com']
# ['laura82', 'gmail.com']
# ['burkecrystal', 'robertson.info']
# ['kochmarco', 'yahoo.com']
# ['gloriathornton', 'jones-ferguson.com']
# ['codylyons', 'hotmail.com']
# ['amandasmith', 'hotmail.com']
# ['marshrebecca', 'hotmail.com']
# ['dprice', 'hotmail.com']
# ['emilyfrank', 'craig-freeman.com']
# ['anthonypatton', 'gmail.com']
# ['riversrichard', 'yahoo.com']
# ['anthonycole', 'henderson.net']
# ['ellisshannon', 'baker.com']
# ['bill20', 'hotmail.com']
# ['dcarr', 'diaz-johnson.com']
# ['jonathancarpenter', 'cook.com']
# ['smithjoe', 'hotmail.com']
# ['parsonsdana', 'gmail.com']
# ['christianchad', 'luna.org']
# ['robertwilson', 'gmail.com']
# ['lisa73', 'kelly.com']
# ['stephanie71', 'hotmail.com']
# ['madams', 'garcia.com']
# ['xbaker', 'hines.com']
# ['qmorris', 'hotmail.com']
# ['osimmons', 'hudson-thomas.biz']
# ['stephanie57', 'gmail.com']
# ['franklinjanice', 'gmail.com']
# ['collinsjames', 'miller-adams.net']
# ['shannon22', 'hotmail.com']
# ['pwhite', 'hotmail.com']
# ['theresa17', 'hotmail.com']
# ['simmonssarah', 'gmail.com']
# ['morganelizabeth', 'hotmail.com']
# ['caldwellmichelle', 'yahoo.com']
# ['virginia14', 'yahoo.com']
# ['brenda71', 'cannon.com']
# ['nelsonmegan', 'green-matthews.com']
# ['xlopez', 'johnson.info']
# ['michelleduffy', 'yahoo.com']
# ['clarkvalerie', 'gmail.com']
# ['maria51', 'gmail.com']
# ['scottwhite', 'yahoo.com']
# ['jgibbs', 'jones.net']
# ['xhernandez', 'bartlett.info']
# ['shawnberry', 'hotmail.com']
# ['shelby01', 'gmail.com']
# ['tararussell', 'hotmail.com']
# ['powelljavier', 'simmons.com']
# ['cory53', 'hotmail.com']
# ['kelly06', 'hernandez.com']
# ['richard86', 'quinn-brown.com']
# ['cooperkyle', 'hart-daniels.com']
# ['ayerslisa', 'smith-stone.net']
# ['davidzimmerman', 'gmail.com']
# ['jessica88', 'allen-bentley.com']
# ['erica26', 'martin-phillips.com']
# ['williamsmelanie', 'yahoo.com']
# ['mary94', 'yahoo.com']
# ['dzamora', 'gmail.com']
# ['stanley83', 'chandler.com']
# ['george28', 'johnson.com']
# ['matthewriley', 'sullivan.com']
# ['julia85', 'ferguson.com']
# ['christopher87', 'hotmail.com']
# ['perrytara', 'owens.com']
# ['dillon89', 'wood.com']
# ['thomas80', 'gmail.com']
# ['hinesamanda', 'gmail.com']
# ['rthomas', 'dalton.com']
# ['scunningham', 'gmail.com']
# ['xanderson', 'webb.biz']
# ['william36', 'payne-morris.com']
# ['scott91', 'gmail.com']
# ['awelch', 'lewis-lewis.com']
# ['harrischarles', 'alexander-smith.info']
# ['tiffany74', 'sanchez-mack.com']
# ['oreed', 'palmer-henry.com']
# ['jennaroy', 'yahoo.com']
# ['friedmanmary', 'christensen.com']
# ['lisawilliams', 'yahoo.com']
# ['ryanhayes', 'yahoo.com']
# ['angelagibson', 'gmail.com']
# ['kellyfernandez', 'burgess.com']
# ['sharonleblanc', 'hotmail.com']
# ['faithgomez', 'marsh-rosales.com']
# ['caitlin30', 'yahoo.com']
# ['krista99', 'ross-maldonado.biz']
# ['cbrown', 'english.org']
# ['angelalewis', 'cruz.org']
# ['henrymaria', 'gmail.com']
# ['amber96', 'perez.org']
# ['douglas63', 'frazier-zimmerman.net']
# ['aramirez', 'bennett.com']
# ['vickie57', 'jackson.com']
# ['joanna69', 'miles-clark.com']
# ['ycox', 'hotmail.com']
# ['melinda11', 'johnson.org']
# ['coreyrivera', 'hotmail.com']
# ['fieldsanthony', 'hotmail.com']
# ['jessicafrancis', 'campbell.biz']
# ['fmahoney', 'hotmail.com']
# ['ernestarnold', 'yahoo.com']
# ['matthew21', 'gmail.com']
# ['wwatson', 'thomas-walsh.com']
# ['hensleyjeffrey', 'gmail.com']
# ['david46', 'jackson-smith.com']
# ['ambercoleman', 'gmail.com']
# ['brittany29', 'green.biz']
# ['jonesdaniel', 'yahoo.com']
# ['qlivingston', 'garcia.info']
# ['vcarson', 'yahoo.com']
# ['burtonscott', 'henry.com']
# ['theresachavez', 'oliver.com']
# ['uwalter', 'randall.com']
# ['kenneth13', 'mccoy.com']
# ['landrews', 'pena-wong.com']
# ['deckerkimberly', 'hotmail.com']
# ['tiffany53', 'sanders-romero.com']
# ['johnconrad', 'rodriguez.com']
# ['davisheather', 'nelson.com']
# ['michael74', 'hotmail.com']
# ['aperry', 'martin.info']
# ['philip41', 'hotmail.com']
# ['esparzaelizabeth', 'yahoo.com']
# ['caseybrown', 'gmail.com']
# ['codybrewer', 'vega.net']
# ['jessicablack', 'gmail.com']
# ['laurathomas', 'gmail.com']
# ['desireecalhoun', 'hotmail.com']
# ['mevans', 'foster-hoffman.com']
# ['phill', 'hotmail.com']
# ['mike51', 'gmail.com']
# ['jason57', 'gmail.com']
# ['brooksemily', 'hotmail.com']
# ['kaylawilson', 'yahoo.com']
# ['gonzalezmatthew', 'jimenez.info']
# ['arichardson', 'hotmail.com']
# ['rbrooks', 'gmail.com']
# ['bryanmitchell', 'andersen.com']
# ['marycarson', 'gmail.com']
# ['lewisjesse', 'gmail.com']
# ['dlawrence', 'yahoo.com']
# ['barneschristina', 'yahoo.com']
# ['angela52', 'hotmail.com']
# ['william72', 'yahoo.com']
# ['megan24', 'yahoo.com']
# ['jennifer53', 'arnold.biz']
# ['stephensjanice', 'martin.com']
# ['youngbrandon', 'harvey.net']
# ['asmith', 'wilkins.info']
# ['jonathan54', 'acosta.biz']
# ['toddanderson', 'chavez.info']
# ['john65', 'yahoo.com']
# ['melissagordon', 'gmail.com']
# ['jeremy90', 'thomas.com']
# ['tanyawong', 'allen.com']
# ['eevans', 'yahoo.com']
# ['charlesburgess', 'greer-higgins.com']
# ['kelly83', 'hotmail.com']
# ['ashley43', 'long.biz']
# ['henry91', 'yahoo.com']
# ['pricetricia', 'williams-roberts.com']
# ['garrettashlee', 'gmail.com']
# ['barbara78', 'yahoo.com']
# ['ajohnson', 'vargas.com']
# ['taylor38', 'oneal.com']
# ['misty58', 'hotmail.com']
# ['williamscassandra', 'kennedy.com']
# ['brownjohn', 'robbins-hughes.com']
# ['josephballard', 'pierce-douglas.com']
# ['kelseyhoward', 'guerrero-bradley.info']
# ['rmeyer', 'hotmail.com']
# ['ericyang', 'yahoo.com']
# ['ecarter', 'stephens.org']
# ['ivance', 'yahoo.com']
# ['marydavidson', 'gmail.com']
# ['kristenlee', 'rowland.biz']
# ['jacquelinewebb', 'hotmail.com']
# ['christopherclark', 'mays.com']
# ['paulcain', 'hotmail.com']
# ['josephgregory', 'yahoo.com']
# ['michaelprice', 'gmail.com']
# ['denisethompson', 'hotmail.com']
# ['figueroastephen', 'yahoo.com']
# ['amymartin', 'estrada.com']
# ['xbrock', 'johnson.info']
# ['elizabethschultz', 'gmail.com']
# ['joshuagonzales', 'short-knight.biz']
# ['gmartinez', 'hotmail.com']
# ['calebrusso', 'yahoo.com']
# ['pbraun', 'yahoo.com']
# ['evelasquez', 'burgess-hall.com']
# ['hillamber', 'perez-herman.org']
# ['kari79', 'yahoo.com']
# ['mary71', 'hotmail.com']
# ['vsummers', 'hotmail.com']
# ['elijah24', 'decker.info']
# ['nicholas52', 'johnson-frazier.com']
# ['jeffrey31', 'hicks-james.com']
# ['davidmelton', 'garza.com']
# ['aaronjones', 'hotmail.com']
# ['patricia41', 'thompson.biz']
# ['timothy70', 'bartlett.com']
# ['rarnold', 'barton.info']
# ['george17', 'hotmail.com']
# ['brianmoore', 'gmail.com']
# ['sharongarcia', 'williams.com']
# ['nealjillian', 'yahoo.com']
# ['deanosborne', 'yahoo.com']
# ['youngkendra', 'proctor.com']
# ['amandasnyder', 'gmail.com']
# ['ksimmons', 'day-ballard.org']
# ['stuartlewis', 'yahoo.com']
# ['elizabethhayes', 'williams.com']
# ['meganmorris', 'gmail.com']
# ['christinasmith', 'hotmail.com']
# ['scott01', 'skinner.com']
# ['andrewdelgado', 'hotmail.com']
# ['sergio83', 'hotmail.com']
# ['christopher98', 'hotmail.com']
# ['mooneyjoseph', 'miller-mack.com']
# ['shepardvernon', 'yahoo.com']
# ['tommyberger', 'gmail.com']
# ['laurajones', 'gmail.com']
# ['nathan86', 'yahoo.com']
# ['thorntonaaron', 'martinez.com']
# ['guerrarebecca', 'hotmail.com']
# ['martinezlisa', 'gmail.com']
# ['zmorris', 'riley.net']
# ['whitekelsey', 'gmail.com']
# ['marcusfisher', 'luna-james.org']
# ['hansonkeith', 'gmail.com']
# ['donaldhall', 'mann.info']
# ['evega', 'clark.net']
# ['hharrell', 'kelly.info']
# ['ctrevino', 'powell.com']
# ['ronald39', 'gmail.com']
# ['garciabenjamin', 'strong.com']
# ['rbenjamin', 'hotmail.com']
# ['barrettjanet', 'yahoo.com']
# ['myersdouglas', 'murphy-knight.com']
# ['ashleymiller', 'williams.org']
# ['lisabryan', 'harrell.com']
# ['rebeccalambert', 'peterson.biz']
# ['samanthasanchez', 'hotmail.com']
# ['rita73', 'gmail.com']
# ['vhinton', 'yahoo.com']
# ['michaelrice', 'hall.com']
# ['fwilson', 'chapman.com']
# ['zlee', 'mckee.info']
# ['theodore33', 'hotmail.com']
# ['yatesdylan', 'gmail.com']
# ['michaelwoodard', 'gmail.com']
# ['ericbest', 'yahoo.com']
# ['pauldorsey', 'yahoo.com']
# ['linda11', 'gmail.com']
# ['klittle', 'yahoo.com']
# ['brendastewart', 'dalton.info']
# ['sarah40', 'gmail.com']
# ['qquinn', 'hotmail.com']
# ['ujones', 'gmail.com']
# ['robertreyes', 'castillo.com']
# ['jacksonrichard', 'moss.org']
# ['hherrera', 'brown.info']
# ['wgould', 'simmons.com']
# ['robertmoss', 'gmail.com']
# ['jacobsongregory', 'richardson-hanson.com']
# ['brent83', 'yahoo.com']
# ['cainkaren', 'yahoo.com']
# ['maryward', 'lane-reed.com']
# ['ecole', 'hotmail.com']
# ['rhonda90', 'johnson-calhoun.com']
# ['garyhenderson', 'hotmail.com']
# ['carol19', 'hotmail.com']
# ['tiffanymoore', 'brewer.org']
# ['baileycrystal', 'yahoo.com']
# ['kimberly31', 'gmail.com']
# ['wpeck', 'robinson-alvarez.info']
# ['wilsonmaria', 'wilkins.com']
# ['lramos', 'stewart.com']
# ['megansheppard', 'white.com']
# ['katrina03', 'yahoo.com']
# ['lwhitney', 'gmail.com']
# ['carlosarcher', 'gmail.com']
# ['lisa25', 'hotmail.com']
# ['breannahenderson', 'nash-pearson.com']
# ['mitchellricky', 'hotmail.com']
# ['samanthasims', 'hotmail.com']
# ['melissaadams', 'hotmail.com']
# ['ecobb', 'williams-flores.org']
# ['colleenburton', 'bryan-smith.com']
# ['chad31', 'gmail.com']
# ['xwarren', 'garza.com']
# ['jeffreyluna', 'yahoo.com']
# ['masonlaurie', 'molina.com']
# ['timothyibarra', 'hotmail.com']
# ['warren08', 'herring.info']
# ['gjacobson', 'brown.com']
# ['guzmandaniel', 'hotmail.com']
# ['stanleyroach', 'gmail.com']
# ['nicholslisa', 'gmail.com']
# ['harriscarl', 'dominguez.com']
# ['james32', 'gmail.com']
# ['paultorres', 'gardner-chandler.com']
# ['denise42', 'gmail.com']
# ['vromero', 'smith.biz']
# ['patricia76', 'dennis.org']
# ['manderson', 'miller.biz']
# ['josephmiles', 'gmail.com']
# ['williamsmatthew', 'francis-james.biz']
# ['kelly30', 'hotmail.com']
# ['randall01', 'yahoo.com']
# ['hensonlindsay', 'graves-fox.com']
# ['briankoch', 'hall.com']
# ['taylorjohn', 'daniel.com']
# ['rgreen', 'hotmail.com']
# ['emurphy', 'yahoo.com']
# ['gregory17', 'craig.org']
# ['duaneross', 'johnson-gonzalez.com']
# ['maryburton', 'yahoo.com']
# ['bakerkaren', 'gmail.com']
# ['anthonywebb', 'castaneda.com']
# ['ismith', 'lewis.com']
# ['keith96', 'ross-garrett.info']
# ['jonesandrew', 'hayes.info']
# ['hallheather', 'gmail.com']
# ['xholloway', 'cook-coleman.info']
# ['christina71', 'lee.net']
# ['jordanrichard', 'gmail.com']
# ['robert57', 'davis.com']
# ['jasoncox', 'haynes-matthews.info']
# ['connie03', 'hotmail.com']
# ['david35', 'banks.com']
# ['michaelbrown', 'gutierrez.com']
# ['hunterpatricia', 'gmail.com']
# ['popejames', 'yahoo.com']
# ['heathergreene', 'gmail.com']
# ['cmatthews', 'hotmail.com']
# ['fdavis', 'hotmail.com']
# ['annetteromero', 'cummings-thomas.com']
# ['julie78', 'hall.com']
# ['amber62', 'gilbert.info']
# ['christian55', 'gmail.com']
# ['allisonlee', 'hotmail.com']
# ['valerieschultz', 'ramirez.com']
# ['mjackson', 'brown.info']
# ['kyle97', 'gmail.com']
# ['sheltonzachary', 'gmail.com']
# ['josephsmith', 'gmail.com']
# ['haleybenjamin', 'gmail.com']
# ['henrycindy', 'gmail.com']
# ['kroman', 'yahoo.com']
# ['cjennings', 'yahoo.com']
# ['jonesjennifer', 'olson.com']
# ['davidsonkaren', 'gmail.com']
# ['brownamy', 'perkins.com']
# ['matthewcontreras', 'bradshaw-skinner.com']
# ['robin89', 'gmail.com']
# ['latashaochoa', 'gmail.com']
# ['reynoldsrick', 'yahoo.com']
# ['jessicaserrano', 'garrett-crawford.net']
# ['zacharyward', 'daniel.net']
# ['justin11', 'porter-smith.info']
# ['vrusso', 'gmail.com']
# ['zjames', 'gmail.com']
# ['zmorris', 'valencia.net']
# ['michellejenkins', 'hotmail.com']
# ['jeff10', 'hotmail.com']
# ['gina95', 'gmail.com']
# ['hmoore', 'gmail.com']
# ['andrewlee', 'ray.com']
# ['rangelbrian', 'hotmail.com']
# ['leslierichards', 'warner.org']
# ['kellycole', 'hotmail.com']
# ['rlewis', 'yahoo.com']
# ['paula72', 'yahoo.com']
# ['taylordiaz', 'roman.net']
# ['pbrown', 'gmail.com']
# ['daltoncarter', 'yahoo.com']
# ['ywhite', 'hotmail.com']
# ['qjohnson', 'yahoo.com']
# ['mark74', 'kirby-stewart.org']
# ['laurenbennett', 'richards.com']
# ['heather24', 'gmail.com']
# ['jacksonmanuel', 'rodriguez-welch.com']
# ['clee', 'vasquez-luna.com']
# ['cranejames', 'white.com']
# ['belindaleon', 'schwartz.com']
# ['denisehamilton', 'novak.biz']
# ['hudsonmichael', 'pace.com']
# ['walterswilliam', 'hotmail.com']
# ['andersonmichael', 'sherman.biz']
# ['kking', 'wise-liu.com']
# ['bberry', 'wright.net']
# ['chelseawilliams', 'lopez.biz']
# ['iroberts', 'gmail.com']
# ['iscott', 'wade-garner.com']
# ['mary85', 'hotmail.com']
# ['tyler16', 'gmail.com']
# ['elizabethmoore', 'reid.net']
# ['rachelford', 'vaughn.com']

# %% [markdown]
# # Great Job!
